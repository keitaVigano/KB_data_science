# %%
import pandas as pd

df = pd.read_csv("../data/authors/authors_internal.csv")
df
# Out:
#     Unnamed: 0     Last name           Name         SSD                orcid  \
# 0            0    Bernasconi   Davide Paolo      MED/01  0000-0001-8771-5428
# 1            1        Bianco         Simone      INF/01  0000-0002-7070-1545
# 2            2       Bissiri  Pier Giovanni   SECS-S/01  0000-0003-3769-6649
# 3            3      Cesarini          Mirko  ING-INF/05  0000-0001-9601-0403
# 4            4        Chicco         Davide      INF/01  0000-0001-9655-7142
# 5            5      Ciavotta        Michele      INF/01  0000-0002-2480-966X
# 6            6  Della Vedova       Gianluca      INF/01  0000-0001-5584-3089
# 7            7       Fattore          Marco   SECS-S/03  0000-0002-6624-8637
# 8            8      Ferretti        Claudio      INF/01  0000-0001-9582-5045
# 9            9       Fersini     Elisabetta      INF/01  0000-0002-8987-100X
# 10          10         Forte     Gianfranco   SECS-P/11  0000-0002-3412-4162
# ...

# %%
grouped = df.groupby("Course")["orcid"].apply(list).reset_index()

# %%
grouped.to_csv('../data/courses/courses.csv')

# %%
df_new = df.drop('Course', axis=1)
df_new = df.drop('Unnamed: 0', axis=1)
df_new.to_csv('../data/authors/authors_internal_prova.csv')
