# %%
import pandas as pd
import requests
import time

# %%
import os
import sys

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.insert(0, parent_dir)

from src.papers_utilities import get_works

# %%
df_authors = pd.read_csv("../data/authors/authors_complete_ds.csv")

# %%
df_papers = pd.DataFrame(columns=["doi", "year", "authors", "author_orcids", "type", "topics"])

# %%
for index, row in df_authors.iterrows():
    family_name = row['Last name']
    given_name = row['Name']
    orcid = row['orcid']
    papers = get_works(orcid, given_name, family_name)
    df_papers = pd.concat([df_papers, papers], ignore_index=True)
    time.sleep(5)

df_papers
# Out:
# Ricerca con ORCID: 0000-0001-8771-5428
# Ricerca con ORCID: 0000-0002-7070-1545
# Ricerca con ORCID: 0000-0003-3769-6649
# Ricerca con ORCID: 0000-0001-9601-0403
# Ricerca con ORCID: 0000-0001-9655-7142
# Ricerca con ORCID: 0000-0002-2480-966X
# Ricerca con ORCID: 0000-0001-5584-3089
# Ricerca con ORCID: 0000-0002-6624-8637
# Ricerca con ORCID: 0000-0001-9582-5045
# Ricerca con ORCID: 0000-0002-8987-100X
# Ricerca con ORCID: 0000-0002-3412-4162
# Ricerca con ORCID: 0000-0001-5186-0199
# Ricerca con ORCID: 0000-0001-7415-0771
# Ricerca con ORCID: 0000-0001-9803-3668
# Ricerca con ORCID: 0000-0001-6864-2702
# Ricerca con ORCID: 0000-0002-4062-0824
# Ricerca con ORCID: 0000-0002-7952-3618
# Ricerca con ORCID: 0000-0002-3436-1395
# Ricerca con ORCID: 0000-0001-9112-0574
# Ricerca con ORCID: 0000-0003-2461-275X
# Ricerca con ORCID: 0000-0002-1801-5118
# Ricerca con ORCID: 0000-0002-6080-8170
# Ricerca con ORCID: 0000-0002-1860-7535
# Ricerca con ORCID: 0000-0002-6331-7211
# Ricerca con ORCID: 0000-0002-3090-4823
# Ricerca con ORCID: 0000-0002-8809-0877
# Ricerca con ORCID: 0000-0003-0606-5852
# Ricerca con ORCID: 0000-0002-1394-0507
# Ricerca con ORCID: 0000-0002-2274-9050
#                                    doi  year  \
# 0            10.1016/j.nut.2022.111687  2022
# 1              10.3390/cancers13071634  2021
# 2           10.1016/j.jhep.2023.09.008  2023
# 3    10.1016/j.ijantimicag.2024.107200  2024
# 4                  10.3390/jpm12101587  2022
# ..                                 ...   ...
# 305          10.1016/j.ins.2019.07.037  2019
# 306       10.1007/978-3-031-88714-7_34  2025
# 307       10.1007/978-3-031-88720-8_52  2025
# 308                    10.1145/3707701  2024
# 309                      10.2196/56038  2025
#
#                                                authors  \
# 0    [Marco Giani, Emanuele Rezoagli, Alice Grassi,...
# 1    [Lavinia Monaco, Maria Gemelli, Irene Gotuzzo,...
# 2    [Riccardo De Carlis, Andrea Lauterio, Davide B...
# 3    [Amedeo De Nicolò, Alice Palermiti, Stefania D...
# 4    [Alessio Gerussi, Damiano Verda, Claudio Cappa...
# ..                                                 ...
# 305  [Gabriella Pasi, Marco Viviani, Alexandre Carton]
# 306  [Luca Herranz-Celotti, Blessing Guembe, Giovan...
# 307  [Udo Kruschwitz, Marinella Petrocchi, Marco Vi...
# 308                  [Paola Impiccichè, Marco Viviani]
# 309  [Xiancheng Li, Emanuela Vaghi, Gabriella Pasi,...
#
#                                          author_orcids             type  \
# 0    [0000-0001-8048-2721, None, None, 0000-0002-18...  journal-article
# 1    [0000-0002-3954-6989, 0000-0003-1143-0252, Non...  journal-article
# 2    [0000-0003-3697-1653, 0000-0001-6110-8582, 000...  journal-article
# 3    [0000-0002-5973-9948, 0000-0003-0860-280X, Non...  journal-article
# 4    [0000-0002-5086-0514, None, 0000-0003-3301-296...  journal-article
# ..                                                 ...              ...
# 305   [0000-0002-6080-8170, 0000-0002-2274-9050, None]  journal-article
# 306  [0000-0003-2460-8099, 0000-0002-7576-9127, 000...     book-chapter
# 307  [0000-0002-5503-0341, 0000-0003-0591-877X, 000...     book-chapter
# 308         [0009-0006-8938-0493, 0000-0002-2274-9050]  journal-article
# 309  [0009-0003-3734-1634, 0009-0002-5166-781X, 000...  journal-article
#
#                                             topics  \
# 0                    Nutrition and Health in Aging
# 1             Lung Cancer Treatments and Mutations
# 2    Organ Transplantation Techniques and Outcomes
# 3                       HIV Research and Treatment
# 4                      Liver Diseases and Immunity
# ..                                             ...
# 305                    Spam and Phishing Detection
# 306        Privacy-Preserving Technologies in Data
# 307                 Misinformation and Its Impacts
# 308          Opinion Dynamics and Social Influence
# 309               Social Media in Health Education
#
#                                                  title
# 0    Low skeletal muscle index and myosteatosis as ...
# 1    Metabolic Parameters as Biomarkers of Response...
# 2    Reply to: “Excellent long-term outcomes after ...
# 3    Plasma, intracellular and lymph node antiretro...
# 4    LLM-PBC: Logic Learning Machine-Based Explaina...
# ..                                                 ...
# 305  A Multi-Criteria Decision Making approach base...
# 306  Can Generative AI Adequately Protect Queries? ...
# 307  ROMCIR 2025: Overview of the 5th Workshop on R...
# 308  Comparing Echo Chamber Detection Metrics: A Cr...
# 309  Understanding the Engagement and Interaction o...
#
# [310 rows x 7 columns]

# %%
# Removing duplicates
temp = df_papers[~df_papers.duplicated(subset=["doi"], keep="first")]
df_papers_no_duplicate = temp[~temp.duplicated(subset=["title"], keep="first")]

df_papers_no_duplicate
# Out:
#                                    doi  year  \
# 0            10.1016/j.nut.2022.111687  2022
# 1              10.3390/cancers13071634  2021
# 2           10.1016/j.jhep.2023.09.008  2023
# 3    10.1016/j.ijantimicag.2024.107200  2024
# 4                  10.3390/jpm12101587  2022
# ..                                 ...   ...
# 300     10.1109/wi-iat59888.2023.00066  2023
# 303           10.1108/lht-12-2020-0317  2021
# 306       10.1007/978-3-031-88714-7_34  2025
# 307       10.1007/978-3-031-88720-8_52  2025
# 308                    10.1145/3707701  2024
#
#                                                authors  \
# 0    [Marco Giani, Emanuele Rezoagli, Alice Grassi,...
# 1    [Lavinia Monaco, Maria Gemelli, Irene Gotuzzo,...
# 2    [Riccardo De Carlis, Andrea Lauterio, Davide B...
# 3    [Amedeo De Nicolò, Alice Palermiti, Stefania D...
# 4    [Alessio Gerussi, Damiano Verda, Claudio Cappa...
# ..                                                 ...
# 300  [Stefano Locci, Luigi Di Caro, Giovanni Livrag...
# 303  [Federico Pianzola, Maurizio Toccu, Marco Vivi...
# 306  [Luca Herranz-Celotti, Blessing Guembe, Giovan...
# 307  [Udo Kruschwitz, Marinella Petrocchi, Marco Vi...
# 308                  [Paola Impiccichè, Marco Viviani]
#
#                                          author_orcids                 type  \
# 0    [0000-0001-8048-2721, None, None, 0000-0002-18...      journal-article
# 1    [0000-0002-3954-6989, 0000-0003-1143-0252, Non...      journal-article
# 2    [0000-0003-3697-1653, 0000-0001-6110-8582, 000...      journal-article
# 3    [0000-0002-5973-9948, 0000-0003-0860-280X, Non...      journal-article
# 4    [0000-0002-5086-0514, None, 0000-0003-3301-296...      journal-article
# ..                                                 ...                  ...
# 300  [0009-0006-9725-2045, 0000-0002-7570-637X, 000...  proceedings-article
# 303  [0000-0001-6634-121X, 0000-0002-5769-1311, 000...      journal-article
# 306  [0000-0003-2460-8099, 0000-0002-7576-9127, 000...         book-chapter
# 307  [0000-0002-5503-0341, 0000-0003-0591-877X, 000...         book-chapter
# 308         [0009-0006-8938-0493, 0000-0002-2274-9050]      journal-article
#
#                                             topics  \
# 0                    Nutrition and Health in Aging
# 1             Lung Cancer Treatments and Mutations
# 2    Organ Transplantation Techniques and Outcomes
# 3                       HIV Research and Treatment
# 4                      Liver Diseases and Immunity
# ..                                             ...
# 300        Privacy-Preserving Technologies in Data
# 303            Impact of Technology on Adolescents
# 306        Privacy-Preserving Technologies in Data
# 307                 Misinformation and Its Impacts
# 308          Opinion Dynamics and Social Influence
#
#                                                  title
# 0    Low skeletal muscle index and myosteatosis as ...
# 1    Metabolic Parameters as Biomarkers of Response...
# 2    Reply to: “Excellent long-term outcomes after ...
# 3    Plasma, intracellular and lymph node antiretro...
# 4    LLM-PBC: Logic Learning Machine-Based Explaina...
# ..                                                 ...
# 300  Explainability of the Effects of Non-Perturbat...
# 303  Readers' engagement through digital social rea...
# 306  Can Generative AI Adequately Protect Queries? ...
# 307  ROMCIR 2025: Overview of the 5th Workshop on R...
# 308  Comparing Echo Chamber Detection Metrics: A Cr...
#
# [287 rows x 7 columns]

# %%
for index, row in df_papers_no_duplicate.iterrows():
    authors = row["author_orcids"]
    if len(authors) < 10:
        df_papers_no_duplicate = df_papers_no_duplicate.drop(index)

df_papers_no_duplicate
# Out:
#                                    doi  year  \
# 0            10.1016/j.nut.2022.111687  2022
# 1              10.3390/cancers13071634  2021
# 2           10.1016/j.jhep.2023.09.008  2023
# 3    10.1016/j.ijantimicag.2024.107200  2024
# 4                  10.3390/jpm12101587  2022
# ..                                 ...   ...
# 282     10.1109/wi-iat59888.2023.00066  2023
# 283           10.1108/lht-12-2020-0317  2021
# 284       10.1007/978-3-031-88714-7_34  2025
# 285       10.1007/978-3-031-88720-8_52  2025
# 286                    10.1145/3707701  2024
#
#                                                authors  \
# 0    ['Marco Giani', 'Emanuele Rezoagli', 'Alice Gr...
# 1    ['Lavinia Monaco', 'Maria Gemelli', 'Irene Got...
# 2    ['Riccardo De Carlis', 'Andrea Lauterio', 'Dav...
# 3    ['Amedeo De Nicolò', 'Alice Palermiti', 'Stefa...
# 4    ['Alessio Gerussi', 'Damiano Verda', 'Claudio ...
# ..                                                 ...
# 282  ['Stefano Locci', 'Luigi Di Caro', 'Giovanni L...
# 283  ['Federico Pianzola', 'Maurizio Toccu', 'Marco...
# 284  ['Luca Herranz-Celotti', 'Blessing Guembe', 'G...
# 285  ['Udo Kruschwitz', 'Marinella Petrocchi', 'Mar...
# 286              ['Paola Impiccichè', 'Marco Viviani']
#
#                                          author_orcids                 type  \
# 0    ['0000-0001-8048-2721', None, None, '0000-0002...      journal-article
# 1    ['0000-0002-3954-6989', '0000-0003-1143-0252',...      journal-article
# 2    ['0000-0003-3697-1653', '0000-0001-6110-8582',...      journal-article
# 3    ['0000-0002-5973-9948', '0000-0003-0860-280X',...      journal-article
# 4    ['0000-0002-5086-0514', None, '0000-0003-3301-...      journal-article
# ..                                                 ...                  ...
# 282  ['0009-0006-9725-2045', '0000-0002-7570-637X',...  proceedings-article
# 283  ['0000-0001-6634-121X', '0000-0002-5769-1311',...      journal-article
# 284  ['0000-0003-2460-8099', '0000-0002-7576-9127',...         book-chapter
# 285  ['0000-0002-5503-0341', '0000-0003-0591-877X',...         book-chapter
# 286     ['0009-0006-8938-0493', '0000-0002-2274-9050']      journal-article
#
#                                             topics  \
# 0                    Nutrition and Health in Aging
# 1             Lung Cancer Treatments and Mutations
# 2    Organ Transplantation Techniques and Outcomes
# 3                       HIV Research and Treatment
# 4                      Liver Diseases and Immunity
# ..                                             ...
# 282        Privacy-Preserving Technologies in Data
# 283            Impact of Technology on Adolescents
# 284        Privacy-Preserving Technologies in Data
# 285                 Misinformation and Its Impacts
# 286          Opinion Dynamics and Social Influence
#
#                                                  title
# 0    Low skeletal muscle index and myosteatosis as ...
# 1    Metabolic Parameters as Biomarkers of Response...
# 2    Reply to: “Excellent long-term outcomes after ...
# 3    Plasma, intracellular and lymph node antiretro...
# 4    LLM-PBC: Logic Learning Machine-Based Explaina...
# ..                                                 ...
# 282  Explainability of the Effects of Non-Perturbat...
# 283  Readers' engagement through digital social rea...
# 284  Can Generative AI Adequately Protect Queries? ...
# 285  ROMCIR 2025: Overview of the 5th Workshop on R...
# 286  Comparing Echo Chamber Detection Metrics: A Cr...
#
# [281 rows x 7 columns]

# %%
df_papers_no_duplicate.to_csv("../data/papers/papers.csv", index=False)
