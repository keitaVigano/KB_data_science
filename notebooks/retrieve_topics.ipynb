# %%
import pandas as pd

# %%
import os
import sys

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.insert(0, parent_dir)

from src.topics_utilities import find_wikidata_entity, get_subfield, get_subfield_by_author

# %%
df_papers = pd.read_csv("../data/papers/papers.csv")
df_papers
# Out:
#                                 doi  year  \
# 0        10.1016/j.jhep.2023.09.008  2023
# 1         10.3390/curroncol28060391  2021
# 2           10.3390/cancers13071745  2021
# 3           10.3390/cancers15082322  2023
# 4        10.3390/healthcare12191988  2024
# ..                              ...   ...
# 230  10.1109/wi-iat59888.2023.00066  2023
# 231        10.1108/lht-12-2020-0317  2021
# 232    10.1007/978-3-031-88714-7_34  2025
# 233    10.1007/978-3-031-88720-8_52  2025
# 234                 10.1145/3707701  2024
#
#                                                authors  \
# 0    ['Riccardo De Carlis', 'Andrea Lauterio', 'Dav...
# 1    ['Nicolò Tamini', 'Luca Gianotti', 'Shadya Dar...
# 2    ['Nicolò Tamini', 'Davide Bernasconi', 'Lorenz...
# 3    ['Stefano Granieri', 'Alessia Kersik', 'Alessa...
# 4    ['Diletta Fabrizi', 'Davide Paolo Bernasconi',...
# ..                                                 ...
# 230  ['Stefano Locci', 'Luigi Di Caro', 'Giovanni L...
# 231  ['Federico Pianzola', 'Maurizio Toccu', 'Marco...
# 232  ['Luca Herranz-Celotti', 'Blessing Guembe', 'G...
# 233  ['Udo Kruschwitz', 'Marinella Petrocchi', 'Mar...
# 234              ['Paola Impiccichè', 'Marco Viviani']
#
#                                          author_orcids                 type  \
# 0    ['0000-0003-3697-1653', '0000-0001-6110-8582',...      journal-article
# 1    ['0000-0003-3917-6831', '0000-0001-7335-8394',...      journal-article
# 2    ['0000-0003-3917-6831', '0000-0001-8771-5428',...      journal-article
# 3    ['0000-0001-9167-3400', None, None, '0000-0003...      journal-article
# 4    ['0000-0002-5152-8804', '0000-0001-8771-5428',...      journal-article
# ..                                                 ...                  ...
# 230  ['0009-0006-9725-2045', '0000-0002-7570-637X',...  proceedings-article
# 231  ['0000-0001-6634-121X', '0000-0002-5769-1311',...      journal-article
# 232  ['0000-0003-2460-8099', '0000-0002-7576-9127',...         book-chapter
# 233  ['0000-0002-5503-0341', '0000-0003-0591-877X',...         book-chapter
# 234     ['0009-0006-8938-0493', '0000-0002-2274-9050']      journal-article
#
#                                 topics  \
# 0                              Surgery
# 1                         Biochemistry
# 2                             Oncology
# 3                             Oncology
# 4                  Clinical Psychology
# ..                                 ...
# 230            Artificial Intelligence
# 231    Sociology and Political Science
# 232            Artificial Intelligence
# 233    Sociology and Political Science
# 234  Statistical and Nonlinear Physics
#
#                                                  title
# 0    Reply to: “Excellent long-term outcomes after ...
# 1    Do Preoperative Transfusions Impact Prognosis ...
# 2    Clinical Validation of the Comprehensive Compl...
# 3    The Role of Non-Peripancreatic Lymph Nodes in ...
# 4    How Are Diagnosis-Related Groups and Staffing ...
# ..                                                 ...
# 230  Explainability of the Effects of Non-Perturbat...
# 231  Readers' engagement through digital social rea...
# 232  Can Generative AI Adequately Protect Queries? ...
# 233  ROMCIR 2025: Overview of the 5th Workshop on R...
# 234  Comparing Echo Chamber Detection Metrics: A Cr...
#
# [235 rows x 7 columns]

# %%
topics = []

for index, row in df_papers.iterrows():
    doi = row["doi"]
    subfield = get_subfield(doi)
    if subfield not in topics and subfield:
        topics.append(subfield)

print(topics)
# Out:
# [['Surgery', 'https://openalex.org/subfields/2746'], ['Biochemistry', 'https://openalex.org/subfields/2704'], ['Oncology', 'https://openalex.org/subfields/2730'], ['Clinical Psychology', 'https://openalex.org/subfields/3203'], ['Experimental and Cognitive Psychology', 'https://openalex.org/subfields/3205'], ['Computer Vision and Pattern Recognition', 'https://openalex.org/subfields/1707'], ['Signal Processing', 'https://openalex.org/subfields/1711'], ['Geology', 'https://openalex.org/subfields/1907'], ['Artificial Intelligence', 'https://openalex.org/subfields/1702'], ['Atomic and Molecular Physics, and Optics', 'https://openalex.org/subfields/3107'], ['Cognitive Neuroscience', 'https://openalex.org/subfields/2805'], ['Environmental Engineering', 'https://openalex.org/subfields/2305'], ['Cardiology and Cardiovascular Medicine', 'https://openalex.org/subfields/2705'], ['Molecular Biology', 'https://openalex.org/subfields/1312'], ['Statistics and Probability', 'https://openalex.org/subfields/2613'], ['Genetics', 'https://openalex.org/subfields/1311'], ['Radiology, Nuclear Medicine and Imaging', 'https://openalex.org/subfields/2741'], ['Computer Networks and Communications', 'https://openalex.org/subfields/1705'], ['Electrical and Electronic Engineering', 'https://openalex.org/subfields/2208'], ['Building and Construction', 'https://openalex.org/subfields/2215'], ['Information Systems', 'https://openalex.org/subfields/1710'], ['Management Science and Operations Research', 'https://openalex.org/subfields/1803'], ['Computer Science Applications', 'https://openalex.org/subfields/1706'], ['Cancer Research', 'https://openalex.org/subfields/1306'], ['Plant Science', 'https://openalex.org/subfields/1110'], ['Software', 'https://openalex.org/subfields/1712'], ['Hardware and Architecture', 'https://openalex.org/subfields/1708'], ['Infectious Diseases', 'https://openalex.org/subfields/2725'], ['Physical and Theoretical Chemistry', 'https://openalex.org/subfields/1606'], ['Computational Theory and Mathematics', 'https://openalex.org/subfields/1703'], ['Sociology and Political Science', 'https://openalex.org/subfields/3312'], ['Economics and Econometrics', 'https://openalex.org/subfields/2002'], ['Social Psychology', 'https://openalex.org/subfields/3207'], ['Radiological and Ultrasound Technology', 'https://openalex.org/subfields/3614'], ['Control and Systems Engineering', 'https://openalex.org/subfields/2207'], ['Health Information Management', 'https://openalex.org/subfields/3605'], [None, None], ['Political Science and International Relations', 'https://openalex.org/subfields/3320'], ['Strategy and Management', 'https://openalex.org/subfields/1408'], ['General Agricultural and Biological Sciences', 'https://openalex.org/subfields/1100'], ['Demography', 'https://openalex.org/subfields/3317'], ['Industrial and Manufacturing Engineering', 'https://openalex.org/subfields/2209'], ['Soil Science', 'https://openalex.org/subfields/1111'], ['Family Practice', 'https://openalex.org/subfields/2714'], ['Biomedical Engineering', 'https://openalex.org/subfields/2204'], ['Statistical and Nonlinear Physics', 'https://openalex.org/subfields/3109'], ['Biophysics', 'https://openalex.org/subfields/1304'], ['Food Science', 'https://openalex.org/subfields/1106'], ['Media Technology', 'https://openalex.org/subfields/2214'], ['Analytical Chemistry', 'https://openalex.org/subfields/1602'], ['Health', 'https://openalex.org/subfields/3306'], ['Health, Toxicology and Mutagenesis', 'https://openalex.org/subfields/2307'], ['General Economics, Econometrics and Finance', 'https://openalex.org/subfields/2000'], ['Finance', 'https://openalex.org/subfields/2003'], ['Modeling and Simulation', 'https://openalex.org/subfields/2611'], ['Tourism, Leisure and Hospitality Management', 'https://openalex.org/subfields/1409'], ['Management, Monitoring, Policy and Law', 'https://openalex.org/subfields/2308'], ['Toxicology', 'https://openalex.org/subfields/3005'], ['Ecology', 'https:/ ...

# %%
df_topics = pd.DataFrame(topics, columns=["topic", "id"])
df_topics = df_topics.dropna()
df_topics
# Out:
#                                     topic                                   id
# 0                                 Surgery  https://openalex.org/subfields/2746
# 1                            Biochemistry  https://openalex.org/subfields/2704
# 2                                Oncology  https://openalex.org/subfields/2730
# 3                     Clinical Psychology  https://openalex.org/subfields/3203
# 4   Experimental and Cognitive Psychology  https://openalex.org/subfields/3205
# ..                                    ...                                  ...
# 60     Pulmonary and Respiratory Medicine  https://openalex.org/subfields/2740
# 61                             Nephrology  https://openalex.org/subfields/2727
# 62             General Health Professions  https://openalex.org/subfields/3600
# 63                             Immunology  https://openalex.org/subfields/2403
# 64         Management Information Systems  https://openalex.org/subfields/1404
#
# [64 rows x 2 columns]

# %%
df_topics["api_url"] = df_topics["id"].apply(
    lambda x: x.replace("https://openalex.org", "https://api.openalex.org") if pd.notna(x) else None
)
df_topics
# Out:
#                                     topic  \
# 0                                 Surgery
# 1                            Biochemistry
# 2                                Oncology
# 3                     Clinical Psychology
# 4   Experimental and Cognitive Psychology
# ..                                    ...
# 60     Pulmonary and Respiratory Medicine
# 61                             Nephrology
# 62             General Health Professions
# 63                             Immunology
# 64         Management Information Systems
#
#                                      id  \
# 0   https://openalex.org/subfields/2746
# 1   https://openalex.org/subfields/2704
# 2   https://openalex.org/subfields/2730
# 3   https://openalex.org/subfields/3203
# 4   https://openalex.org/subfields/3205
# ..                                  ...
# 60  https://openalex.org/subfields/2740
# 61  https://openalex.org/subfields/2727
# 62  https://openalex.org/subfields/3600
# 63  https://openalex.org/subfields/2403
# 64  https://openalex.org/subfields/1404
#
#                                     api_url
# 0   https://api.openalex.org/subfields/2746
# 1   https://api.openalex.org/subfields/2704
# 2   https://api.openalex.org/subfields/2730
# 3   https://api.openalex.org/subfields/3203
# 4   https://api.openalex.org/subfields/3205
# ..                                      ...
# 60  https://api.openalex.org/subfields/2740
# 61  https://api.openalex.org/subfields/2727
# 62  https://api.openalex.org/subfields/3600
# 63  https://api.openalex.org/subfields/2403
# 64  https://api.openalex.org/subfields/1404
#
# [64 rows x 3 columns]

# %%
df_topics["wikidata_uri"] = df_topics["api_url"].apply(find_wikidata_entity)
df_topics
# Out:
#                                     topic  \
# 0                                 Surgery
# 1                            Biochemistry
# 2                                Oncology
# 3                     Clinical Psychology
# 4   Experimental and Cognitive Psychology
# ..                                    ...
# 60     Pulmonary and Respiratory Medicine
# 61                             Nephrology
# 62             General Health Professions
# 63                             Immunology
# 64         Management Information Systems
#
#                                      id  \
# 0   https://openalex.org/subfields/2746
# 1   https://openalex.org/subfields/2704
# 2   https://openalex.org/subfields/2730
# 3   https://openalex.org/subfields/3203
# 4   https://openalex.org/subfields/3205
# ..                                  ...
# 60  https://openalex.org/subfields/2740
# 61  https://openalex.org/subfields/2727
# 62  https://openalex.org/subfields/3600
# 63  https://openalex.org/subfields/2403
# 64  https://openalex.org/subfields/1404
#
#                                     api_url  \
# 0   https://api.openalex.org/subfields/2746
# 1   https://api.openalex.org/subfields/2704
# 2   https://api.openalex.org/subfields/2730
# 3   https://api.openalex.org/subfields/3203
# 4   https://api.openalex.org/subfields/3205
# ..                                      ...
# 60  https://api.openalex.org/subfields/2740
# 61  https://api.openalex.org/subfields/2727
# 62  https://api.openalex.org/subfields/3600
# 63  https://api.openalex.org/subfields/2403
# 64  https://api.openalex.org/subfields/1404
#
#                                 wikidata_uri
# 0      http://www.wikidata.org/entity/Q40821
# 1       http://www.wikidata.org/entity/Q7094
# 2     http://www.wikidata.org/entity/Q162555
# 3     http://www.wikidata.org/entity/Q199906
# 4       https://www.wikidata.org/wiki/Q23373
# ..                                       ...
# 60  http://www.wikidata.org/entity/Q96730933
# 61    http://www.wikidata.org/entity/Q177635
# 62    https://www.wikidata.org/wiki/Q3922583
# 63    http://www.wikidata.org/entity/Q101929
# 64     http://www.wikidata.org/entity/Q61905
#
# [64 rows x 4 columns]

# %%
df_topics[["topic", "wikidata_uri"]].to_csv("../data/topics/topics.csv", index=False)

# %% [markdown]
# Drop topics from authors

# %%
df_authors = pd.read_csv("../data/authors/authors_final.csv")
df_authors.head()
# Out:
#                       Name         SSD                orcid  hindex  \
# 0  Davide Paolo Bernasconi      MED/01  0000-0001-8771-5428    24.0
# 1            Simone Bianco      INF/01  0000-0002-7070-1545    34.0
# 2    Pier Giovanni Bissiri   SECS-S/01  0000-0003-3769-6649     7.0
# 3           Mirko Cesarini  ING-INF/05  0000-0001-9601-0403    15.0
# 4            Davide Chicco      INF/01  0000-0001-9655-7142    27.0
#
#                         openalex id  \
# 0  https://openalex.org/A5050512903
# 1  https://openalex.org/A5013570285
# 2  https://openalex.org/A5074768639
# 3  https://openalex.org/A5049259722
# 4  https://openalex.org/A5011556172
#
#                                 past_institutions_id  \
# 0  ['https://openalex.org/I4210094195', 'https://...
# 1  ['https://openalex.org/I189158943', 'https://o...
# 2  ['https://openalex.org/I9360294', 'https://ope...
# 3  ['https://openalex.org/I4210135780', 'https://...
# 4  ['https://openalex.org/I185261750', 'https://o...
#
#                                               topics  DS Department  \
# 0  ['Liver Disease Diagnosis and Treatment', 'Liv...              1
# 1  ['Image Enhancement Techniques', 'Color Scienc...              1
# 2  ['Bayesian Methods and Mixture Models', 'Soil ...              1
# 3  ['Data Quality and Management', 'Semantic Web ...              1
# 4  ['Gene expression and cancer classification', ...              1
#
#                            ins_id
# 0  https://openalex.org/I66752286
# 1  https://openalex.org/I66752286
# 2  https://openalex.org/I66752286
# 3  https://openalex.org/I66752286
# 4  https://openalex.org/I66752286

# %%
df_authors.drop("topics", axis = 1, inplace=True)

# %%
df_authors.to_csv("../data/authors/authors_final.csv", index=False)
