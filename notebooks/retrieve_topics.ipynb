# %%
import pandas as pd

# %%
import os
import sys

current_dir = os.path.dirname(os.path.abspath(__file__)) if '__file__' in globals() else os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.insert(0, parent_dir)

from src.topics_utilities import find_wikidata_entity, get_subfield, get_subfield_by_author

# %%
df_papers = pd.read_csv("../data/papers/papers.csv")
df_papers
# Out:
#                                 doi  year  \
# 0        10.1016/j.jhep.2023.09.008  2023
# 1         10.3390/curroncol28060391  2021
# 2           10.3390/cancers13071745  2021
# 3           10.3390/cancers15082322  2023
# 4        10.3390/healthcare12191988  2024
# ..                              ...   ...
# 230  10.1109/wi-iat59888.2023.00066  2023
# 231        10.1108/lht-12-2020-0317  2021
# 232    10.1007/978-3-031-88714-7_34  2025
# 233    10.1007/978-3-031-88720-8_52  2025
# 234                 10.1145/3707701  2024
#
#                                                authors  \
# 0    ['Riccardo De Carlis', 'Andrea Lauterio', 'Dav...
# 1    ['Nicolò Tamini', 'Luca Gianotti', 'Shadya Dar...
# 2    ['Nicolò Tamini', 'Davide Bernasconi', 'Lorenz...
# 3    ['Stefano Granieri', 'Alessia Kersik', 'Alessa...
# 4    ['Diletta Fabrizi', 'Davide Paolo Bernasconi',...
# ..                                                 ...
# 230  ['Stefano Locci', 'Luigi Di Caro', 'Giovanni L...
# 231  ['Federico Pianzola', 'Maurizio Toccu', 'Marco...
# 232  ['Luca Herranz-Celotti', 'Blessing Guembe', 'G...
# 233  ['Udo Kruschwitz', 'Marinella Petrocchi', 'Mar...
# 234              ['Paola Impiccichè', 'Marco Viviani']
#
#                                          author_orcids                 type  \
# 0    ['0000-0003-3697-1653', '0000-0001-6110-8582',...      journal-article
# 1    ['0000-0003-3917-6831', '0000-0001-7335-8394',...      journal-article
# 2    ['0000-0003-3917-6831', '0000-0001-8771-5428',...      journal-article
# 3    ['0000-0001-9167-3400', None, None, '0000-0003...      journal-article
# 4    ['0000-0002-5152-8804', '0000-0001-8771-5428',...      journal-article
# ..                                                 ...                  ...
# 230  ['0009-0006-9725-2045', '0000-0002-7570-637X',...  proceedings-article
# 231  ['0000-0001-6634-121X', '0000-0002-5769-1311',...      journal-article
# 232  ['0000-0003-2460-8099', '0000-0002-7576-9127',...         book-chapter
# 233  ['0000-0002-5503-0341', '0000-0003-0591-877X',...         book-chapter
# 234     ['0009-0006-8938-0493', '0000-0002-2274-9050']      journal-article
#
#                                             topics  \
# 0    Organ Transplantation Techniques and Outcomes
# 1                 Blood transfusion and management
# 2            Colorectal Cancer Surgical Treatments
# 3         Pancreatic and Hepatic Oncology Research
# 4                    Health and Well-being Studies
# ..                                             ...
# 230        Privacy-Preserving Technologies in Data
# 231            Impact of Technology on Adolescents
# 232        Privacy-Preserving Technologies in Data
# 233                 Misinformation and Its Impacts
# 234          Opinion Dynamics and Social Influence
#
#                                                  title
# 0    Reply to: “Excellent long-term outcomes after ...
# 1    Do Preoperative Transfusions Impact Prognosis ...
# 2    Clinical Validation of the Comprehensive Compl...
# 3    The Role of Non-Peripancreatic Lymph Nodes in ...
# 4    How Are Diagnosis-Related Groups and Staffing ...
# ..                                                 ...
# 230  Explainability of the Effects of Non-Perturbat...
# 231  Readers' engagement through digital social rea...
# 232  Can Generative AI Adequately Protect Queries? ...
# 233  ROMCIR 2025: Overview of the 5th Workshop on R...
# 234  Comparing Echo Chamber Detection Metrics: A Cr...
#
# [235 rows x 7 columns]

# %%
df_bicocca = pd.read_csv("../data/authors/authors_internal_prova.csv")
df_bicocca.head()
# Out:
#    Unnamed: 0   Last name           Name         SSD                orcid  \
# 0           0  Bernasconi   Davide Paolo      MED/01  0000-0001-8771-5428
# 1           1      Bianco         Simone      INF/01  0000-0002-7070-1545
# 2           2     Bissiri  Pier Giovanni   SECS-S/01  0000-0003-3769-6649
# 3           3    Cesarini          Mirko  ING-INF/05  0000-0001-9601-0403
# 4           4      Chicco         Davide      INF/01  0000-0001-9655-7142
#
#                                       Course  hindex  \
# 0               Data Science Lab in Medicine    24.0
# 1        Digital Signal and Image Management    34.0
# 2  Foundations of Probability and Statistics     7.0
# 3                            Service Science    15.0
# 4                            Green Computing    27.0
#
#                         openalex id  \
# 0  https://openalex.org/A5050512903
# 1  https://openalex.org/A5013570285
# 2  https://openalex.org/A5074768639
# 3  https://openalex.org/A5049259722
# 4  https://openalex.org/A5011556172
#
#                                      institutions id  \
# 0  ['https://openalex.org/I66752286', 'https://op...
# 1  ['https://openalex.org/I66752286', 'https://op...
# 2  ['https://openalex.org/I66752286', 'https://op...
# 3  ['https://openalex.org/I66752286', 'https://op...
# 4  ['https://openalex.org/I185261750', 'https://o...
#
#                                    institutions name  \
# 0  ['University of Milano-Bicocca', 'Azienda Soci...
# 1  ['University of Milano-Bicocca', 'University o...
# 2  ['University of Milano-Bicocca', 'University o...
# 3  ['University of Milano-Bicocca', 'Center for N...
# 4  ['University of Toronto', 'University of Milan...
#
#                                               topics
# 0  ['Liver Disease Diagnosis and Treatment', 'Liv...
# 1  ['Image Enhancement Techniques', 'Color Scienc...
# 2  ['Bayesian Methods and Mixture Models', 'Soil ...
# 3  ['Data Quality and Management', 'Semantic Web ...
# 4  ['Gene expression and cancer classification', ...

# %%
topics = []

for index, row in df_papers.iterrows():
    doi = row["doi"]
    subfield = get_subfield(doi)
    if subfield not in topics and subfield:
        topics.append(subfield)

print(topics)
# Out:
# ['Surgery', 'Biochemistry', 'Oncology', 'Clinical Psychology', 'Experimental and Cognitive Psychology', 'Computer Vision and Pattern Recognition', 'Signal Processing', 'Geology', 'Artificial Intelligence', 'Atomic and Molecular Physics, and Optics', 'Cognitive Neuroscience', 'Environmental Engineering', 'Cardiology and Cardiovascular Medicine', 'Molecular Biology', 'Statistics and Probability', 'Genetics', 'Radiology, Nuclear Medicine and Imaging', 'Computer Networks and Communications', 'Electrical and Electronic Engineering', 'Building and Construction', 'Information Systems', 'Management Science and Operations Research', 'Computer Science Applications', 'Cancer Research', 'Plant Science', 'Software', 'Hardware and Architecture', 'Infectious Diseases', 'Physical and Theoretical Chemistry', 'Computational Theory and Mathematics', 'Sociology and Political Science', 'Economics and Econometrics', 'Social Psychology', 'Radiological and Ultrasound Technology', 'Control and Systems Engineering', 'Health Information Management', 'Political Science and International Relations', 'Strategy and Management', 'General Agricultural and Biological Sciences', 'Demography', 'Industrial and Manufacturing Engineering', 'Soil Science', 'Family Practice', 'Biomedical Engineering', 'Statistical and Nonlinear Physics', 'Biophysics', 'Food Science', 'Media Technology', 'Analytical Chemistry', 'Health', 'Health, Toxicology and Mutagenesis', 'General Economics, Econometrics and Finance', 'Finance', 'Modeling and Simulation', 'Tourism, Leisure and Hospitality Management', 'Management, Monitoring, Policy and Law', 'Toxicology', 'Ecology', 'Endocrinology, Diabetes and Metabolism', 'Pulmonary and Respiratory Medicine', 'Nephrology', 'General Health Professions', 'Immunology', 'Management Information Systems']

# %%
for index, row in df_bicocca.iterrows():
    orcid = row["orcid"]
    subfields = get_subfield_by_author(orcid)
    if subfield not in topics and subfield:
        for subfield in subfields:
            topics.append(subfield)

print(topics)
# Out:
# ['Surgery', 'Biochemistry', 'Oncology', 'Clinical Psychology', 'Experimental and Cognitive Psychology', 'Computer Vision and Pattern Recognition', 'Signal Processing', 'Geology', 'Artificial Intelligence', 'Atomic and Molecular Physics, and Optics', 'Cognitive Neuroscience', 'Environmental Engineering', 'Cardiology and Cardiovascular Medicine', 'Molecular Biology', 'Statistics and Probability', 'Genetics', 'Radiology, Nuclear Medicine and Imaging', 'Computer Networks and Communications', 'Electrical and Electronic Engineering', 'Building and Construction', 'Information Systems', 'Management Science and Operations Research', 'Computer Science Applications', 'Cancer Research', 'Plant Science', 'Software', 'Hardware and Architecture', 'Infectious Diseases', 'Physical and Theoretical Chemistry', 'Computational Theory and Mathematics', 'Sociology and Political Science', 'Economics and Econometrics', 'Social Psychology', 'Radiological and Ultrasound Technology', 'Control and Systems Engineering', 'Health Information Management', 'Political Science and International Relations', 'Strategy and Management', 'General Agricultural and Biological Sciences', 'Demography', 'Industrial and Manufacturing Engineering', 'Soil Science', 'Family Practice', 'Biomedical Engineering', 'Statistical and Nonlinear Physics', 'Biophysics', 'Food Science', 'Media Technology', 'Analytical Chemistry', 'Health', 'Health, Toxicology and Mutagenesis', 'General Economics, Econometrics and Finance', 'Finance', 'Modeling and Simulation', 'Tourism, Leisure and Hospitality Management', 'Management, Monitoring, Policy and Law', 'Toxicology', 'Ecology', 'Endocrinology, Diabetes and Metabolism', 'Pulmonary and Respiratory Medicine', 'Nephrology', 'General Health Professions', 'Immunology', 'Management Information Systems']

# %%
df_topics = pd.DataFrame({"topic": topics})
df_topics
# Out:
#                                     topic
# 0                                 Surgery
# 1                            Biochemistry
# 2                                Oncology
# 3                     Clinical Psychology
# 4   Experimental and Cognitive Psychology
# ..                                    ...
# 59     Pulmonary and Respiratory Medicine
# 60                             Nephrology
# 61             General Health Professions
# 62                             Immunology
# 63         Management Information Systems
#
# [64 rows x 1 columns]

# %%
df_topics["wikidata_uri"] = df_topics["topic"].apply(find_wikidata_entity)
df_topics
# Out:
#                                     topic  \
# 0                                 Surgery
# 1                            Biochemistry
# 2                                Oncology
# 3                     Clinical Psychology
# 4   Experimental and Cognitive Psychology
# ..                                    ...
# 59     Pulmonary and Respiratory Medicine
# 60                             Nephrology
# 61             General Health Professions
# 62                             Immunology
# 63         Management Information Systems
#
#                                 wikidata_uri
# 0    http://www.wikidata.org/entity/Q3978151
# 1     http://www.wikidata.org/entity/Q764876
# 2    http://www.wikidata.org/entity/Q1998293
# 3   http://www.wikidata.org/entity/Q96331017
# 4                                       None
# ..                                       ...
# 59                                      None
# 60  http://www.wikidata.org/entity/Q15750101
# 61                                      None
# 62  http://www.wikidata.org/entity/Q15754984
# 63  http://www.wikidata.org/entity/Q96331842
#
# [64 rows x 2 columns]

# %%
df_topics.to_csv("../data/topics/topics.csv", index = False)
