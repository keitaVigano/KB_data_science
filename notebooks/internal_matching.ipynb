# %% [markdown]
# # Match not found Professors

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from sentence_transformers import SentenceTransformer, util

# %% [markdown]
# ## Retrieve all the authors

# %%
df = pd.read_csv("../data/authors/authors_data_science.csv")
import requests

def search_orcid_bicocca(given_name, family_name):
    base_url = "https://pub.orcid.org/v3.0/expanded-search/"
    query = f"given-names:{given_name} AND family-name:{family_name}"

    headers = {
        "Accept": "application/json"
    }

    params = {
        "q": query
    }

    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code != 200:
        print(f"Errore nella richiesta: {response.status_code}")
        return None

    results = response.json().get("expanded-result", [])

    if not results:
        print("Nessun risultato trovato.")
        return None

    for res in results:
        affiliations = res.get("institution-name", [])
        if any("bicocca" in aff.lower() for aff in affiliations):
            full_name = res.get("given-names", "") + " " + res.get("family-name", "")
            orcid = res.get("orcid-id", "N/A")
            print(f"Trovato: {full_name} -> ORCID: {orcid}")
            return orcid

    print("Nessun ORCID trovato associato alla Bicocca.")
    return None

# %%
for index, row in df.iterrows():
        family_name = row['Last name']
        given_name = row['Name']
        orcid = search_orcid_bicocca(given_name, family_name)
    
        df.loc[index, "orcid"] = orcid
# Out:
# Nessun risultato trovato.
# Nessun ORCID trovato associato alla Bicocca.
# Trovato: Simone  -> ORCID: 0000-0002-7070-1545
# Trovato: Pier Giovanni  -> ORCID: 0000-0003-3769-6649
# Nessun ORCID trovato associato alla Bicocca.
# Trovato: Davide  -> ORCID: 0000-0001-9655-7142
# Trovato: Michele  -> ORCID: 0000-0002-2480-966X
# Trovato: Gianluca  -> ORCID: 0000-0001-5584-3089
# Nessun ORCID trovato associato alla Bicocca.
# Nessun ORCID trovato associato alla Bicocca.
# Nessun ORCID trovato associato alla Bicocca.
# Nessun ORCID trovato associato alla Bicocca.
# Trovato: Gianfranco  -> ORCID: 0000-0002-3412-4162
# Trovato: Gabriele  -> ORCID: 0000-0001-5186-0199
# Trovato: marco  -> ORCID: 0000-0001-7415-0771
# Trovato: Andrea  -> ORCID: 0000-0001-9803-3668
# Trovato: Fabio  -> ORCID: 0000-0001-6864-2702
# Trovato: Enza  -> ORCID: 0000-0002-4062-0824
# Trovato: gianna  -> ORCID: 0000-0002-7952-3618
# Trovato: Enrico  -> ORCID: 0000-0002-3436-1395
# Trovato: Paolo  -> ORCID: 0000-0001-9112-0574
# Trovato: Marco  -> ORCID: 0000-0003-2461-275X
# Trovato: MATTEO  -> ORCID: 0000-0002-1801-5118
# Trovato: Gabriella  -> ORCID: 0000-0002-6080-8170
# Trovato: Matteo  -> ORCID: 0000-0002-1860-7535
# Trovato: Fulvia  -> ORCID: 0000-0002-6331-7211
# Trovato: Dario  -> ORCID: 0000-0002-3090-4823
# Trovato: Luca  -> ORCID: 0000-0002-8809-0877
# Nessun ORCID trovato associato alla Bicocca.
# Nessun ORCID trovato associato alla Bicocca.
# Trovato: Marco  -> ORCID: 0000-0002-2274-9050

# %%
not_found = df[df["orcid"].isna()]
not_found
# Out:
#       Last name           Name         SSD orcid
# 0     Andreotti  Alberta Argia      SPS/09  None
# 1    Bernasconi   Davide Paolo      MED/01  None
# 4      Cesarini          Mirko  ING-INF/05  None
# 8   Di Domenica           Nico   SECS-P/08  None
# 9       Fattore          Marco   SECS-S/03  None
# 10     Ferretti        Claudio      INF/01  None
# 11      Fersini     Elisabetta      INF/01  None
# 28       Rebora          Paola      MED/01  None
# 29       Stella  Fabio Antonio      MAT/09  None

# %% [markdown]
# ### Scrape Information of not found professors

# %%
def generate_profile_url(name, surname):
    """Genera lo slug URL del profilo unimib in base al nome e cognome."""
    full_name = f"{name} {surname}".lower()
    slug = "-".join(full_name.split())
    return f"https://www.unimib.it/{slug}"

def scrape_full_profile(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"⚠️ Errore {response.status_code} per URL: {url}")
            return {}
    except Exception as e:
        print(f"❌ Richiesta fallita per {url}: {e}")
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    data = {}

    # Email
    email_tag = soup.find("a", href=lambda x: x and "mailto:" in x)
    if email_tag:
        data["email"] = email_tag.get_text(strip=True)

    # Phone number
    phone_tag = soup.find("a", href=lambda x: x and "tel:" in x)
    if phone_tag:
        data["phone"] = phone_tag.get_text(strip=True)

    # Campi etichettati
    fields = {
        "Ruolo": "role",
        "Settore scientifico disciplinare": "ssd",
        "Gruppo scientifico disciplinare": "gsd",
        "Afferenza": "department",
        "Stanza": "office"
    }

    for label, key in fields.items():
        try:
            label_elem = soup.find("div", string=lambda x: x and label in x)
            if label_elem:
                sibling = label_elem.find_next_sibling("div")
                if sibling:
                    data[key] = sibling.get_text(strip=True)
        except Exception as e:
            print(f"⚠️ Errore estraendo {label}: {e}")

    # === Nuova estrazione pubblicazioni da <li> sotto "Pubblicazioni"
    try:
        pub_title = soup.find(lambda tag: tag.name in ["h2", "h3"] and "pubblicazioni" in tag.get_text(strip=True).lower())
        if pub_title:
            pub_list = pub_title.find_next("ul")
            if pub_list:
                items = pub_list.find_all("li")
                publications = [item.get_text(separator=" ", strip=True) for item in items]
                data["publications"] = "; ".join(publications[:5])
    except Exception as e:
        print(f"⚠️ Errore durante l'estrazione delle pubblicazioni: {e}")

    return data

    """Effettua scraping della pagina profilo Unimib, estraendo info e pubblicazioni."""
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200:
            print(f"⚠️ Errore {response.status_code} per URL: {url}")
            return {}
    except Exception as e:
        print(f"❌ Richiesta fallita per {url}: {e}")
        return {}

    soup = BeautifulSoup(response.text, "html.parser")
    data = {}

    # Email
    email_tag = soup.find("a", href=lambda x: x and "mailto:" in x)
    if email_tag:
        data["email"] = email_tag.get_text(strip=True)

    # Phone number
    phone_tag = soup.find("a", href=lambda x: x and "tel:" in x)
    if phone_tag:
        data["phone"] = phone_tag.get_text(strip=True)

    # Campi etichettati
    fields = {
        "Ruolo": "role",
        "Settore scientifico disciplinare": "ssd",
        "Gruppo scientifico disciplinare": "gsd",
        "Afferenza": "department",
        "Stanza": "office"
    }

    for label, key in fields.items():
        try:
            label_elem = soup.find("div", string=lambda x: x and label in x)
            if label_elem:
                sibling = label_elem.find_next_sibling("div")
                if sibling:
                    data[key] = sibling.get_text(strip=True)
        except Exception as e:
            print(f"⚠️ Errore estraendo {label}: {e}")

    # Pubblicazioni (blocco "biblio")
    try:
        pub_section = soup.find("div", class_="biblio")
        if pub_section:
            entries = pub_section.find_all("div", class_="biblio-entry")
            publications = [entry.get_text(separator=" ", strip=True) for entry in entries]
            data["publications"] = "; ".join(publications[:5])  # Puoi cambiare 5 in un numero maggiore
    except Exception as e:
        print(f"⚠️ Errore estraendo pubblicazioni: {e}")

    return data


# Lista professori
professori = [
    ("Alberta Argia", "Andreotti"),
    ("Davide Paolo", "Bernasconi"),
    ("Mirko", "Cesarini"),
    ("Nico", "Di Domenica"),
    ("Marco", "Fattore"),
    ("Claudio", "Ferretti"),
    ("Elisabetta", "Fersini"),
    ("Paola", "Rebora"),
    ("Fabio Antonio", "Stella"),
]

results = []
for name, surname in professori:
    profile_url = generate_profile_url(name, surname)
    print(f"🔍 Analizzando {profile_url}")
    info = scrape_full_profile(profile_url)
    result = {
        "name": name,
        "surname": surname,
        "profile_url": profile_url,
        **info
    }
    results.append(result)
    time.sleep(1.5)  # evita rate limiting

# Crea DataFrame finale
df = pd.DataFrame(results)

# Mostra/Salva
df
# Out:
# 🔍 Analizzando https://www.unimib.it/alberta-argia-andreotti
# 🔍 Analizzando https://www.unimib.it/davide-paolo-bernasconi
# 🔍 Analizzando https://www.unimib.it/mirko-cesarini
# 🔍 Analizzando https://www.unimib.it/nico-di-domenica
# ⚠️ Errore 404 per URL: https://www.unimib.it/nico-di-domenica
# 🔍 Analizzando https://www.unimib.it/marco-fattore
# 🔍 Analizzando https://www.unimib.it/claudio-ferretti
# 🔍 Analizzando https://www.unimib.it/elisabetta-fersini
# 🔍 Analizzando https://www.unimib.it/paola-rebora
# 🔍 Analizzando https://www.unimib.it/fabio-antonio-stella
# ✅ Scraping completato.
#             name      surname                                    profile_url  \
# 0  Alberta Argia    Andreotti  https://www.unimib.it/alberta-argia-andreotti
# 1   Davide Paolo   Bernasconi  https://www.unimib.it/davide-paolo-bernasconi
# 2          Mirko     Cesarini           https://www.unimib.it/mirko-cesarini
# 3           Nico  Di Domenica         https://www.unimib.it/nico-di-domenica
# 4          Marco      Fattore            https://www.unimib.it/marco-fattore
# 5        Claudio     Ferretti         https://www.unimib.it/claudio-ferretti
# 6     Elisabetta      Fersini       https://www.unimib.it/elisabetta-fersini
# 7          Paola       Rebora             https://www.unimib.it/paola-rebora
# 8  Fabio Antonio       Stella     https://www.unimib.it/fabio-antonio-stella
#
#         phone                     role  \
# 0  0264487579  Professoressa ordinaria
# 1  0264488098     Professore associato
# 2  0264485849              Ricercatore
# 3         NaN                      NaN
# 4  0264483227     Professore ordinario
# 5  0264487819     Professore associato
# 6  0264487896  Professoressa associata
# 7  0264488165  Professoressa associata
# 8  0264487837     Professore ordinario
#
#                                                  ssd  \
# 0  Sociologia dei processi economici e del lavoro...
# 1                      Statistica medica (MEDS-24/A)
# 2  Sistemi di elaborazione delle informazioni (II...
# 3                                                NaN
# 4                   Statistica economica (STAT-02/A)
# 5                            Informatica (INFO-01/A)
# 6                            Informatica (INFO-01/A)
# 7                      Statistica medica (MEDS-24/A)
# 8                            Informatica (INFO-01/A)
#
#                                                  gsd  \
# 0  SOCIOLOGIA DEI PROCESSI ECONOMICI, DEL LAVORO,...
# 1  STATISTICA MEDICA, IGIENE GENERALE E APPLICATA...
# 2  SISTEMI DI ELABORAZIONE DELLE INFORMAZIONI (09...
# 3                                                NaN
# 4                  STATISTICA ECONOMICA (13/STAT-02)
# 5                           INFORMATICA (01/INFO-01)
# 6                           INFORMATICA (01/INFO-01)
# 7  STATISTICA MEDICA, IGIENE GENERALE E APPLICATA...
# 8                           INFORMATICA (01/INFO-01)
#
#                                           department  \
# 0       DIPARTIMENTO DI SOCIOLOGIA E RICERCA SOCIALE
# 1  DIPARTIMENTO DI MEDICINA E CHIRURGIA (SCHOOL O...
# 2   DIPARTIMENTO DI STATISTICA E METODI QUANTITATIVI
# 3                                                NaN
# 4   DIPARTIMENTO DI STATISTICA E METODI QUANTITATIVI
# 5  DIPARTIMENTO DI INFORMATICA, SISTEMISTICA E CO...
# 6  DIPARTIMENTO DI INFORMATICA, SISTEMISTICA E CO...
# 7  DIPARTIMENTO DI MEDICINA E CHIRURGIA (SCHOOL O...
# 8  DIPARTIMENTO DI INFORMATICA, SISTEMISTICA E CO...
#
#                           office  \
# 0   U07,  Piano: 3,  Stanza: 352
# 1  U28,  Piano: 0,  Stanza: T003
# 2  U07,  Piano: 4,  Stanza: 4133
# 3                            NaN
# 4  U07,  Piano: 4,  Stanza: 4133
# 5  U14,  Piano: 2,  Stanza: 2053
# 6  U14,  Piano: 2,  Stanza: 2016
# 7  U28,  Piano: 0,  Stanza: T002
# 8  U14,  Piano: 2,  Stanza: 2046
#
#                                         publications
# 0  Andreotti, A., Coletto, D., Rio, A. (2024). St...
# 1  Capsoni, N., Azin, G., Scarnera, M., Bettina, ...
# 2  Ravenda, F., Cesarini, M., Peluso, S., Mira, A...
# 3                                                NaN
# 4  Fattore, M. (2025). Complexity reduction of mu...
# 5  Saletta, M., Ferretti, C. (2024). Exploring th...
# 6  Batini, C., Santucci, G., Palmonari, M., Bella...
# 7  Rebora, P., Antolini, L., Glidden, D., & Valse...
# 8  Acerbi, E., Viganò, E., Poidinger, M., Mortell...

# %%
df.columns
# Out:
# Index(['name', 'surname', 'profile_url', 'phone', 'role', 'ssd', 'gsd',
#        'department', 'office', 'publications'],
#       dtype='object')

# %% [markdown]
# ### search all profile with same name of missing professors

# %%
def search_orcid_detailed(given_name, family_name):
    base_url = "https://pub.orcid.org/v3.0/expanded-search/"
    headers = {"Accept": "application/json"}
    query = f"given-names:{given_name} AND family-name:{family_name}"
    params = {"q": query}

    try:
        res = requests.get(base_url, headers=headers, params=params, timeout=10)
        res.raise_for_status()
    except Exception as e:
        print(f"❌ Errore per {given_name} {family_name}: {e}")
        return []

    data = res.json()
    results = data.get("expanded-result", []) or []

    entries = []
    for result in results:
        entry = {
            "ORCID ID": result.get("orcid-id"),
            "First Name": result.get("given-names"),
            "Last Name": result.get("family-names"),
            "Other Names": "; ".join(result.get("other-name", []) or []),
            "Affiliations": "; ".join(result.get("institution-name", []) or [])
        }
        entries.append(entry)

    return entries

# Lista professori
professori = [
    ("Alberta Argia", "Andreotti"),
    ("Davide Paolo", "Bernasconi"),
    ("Mirko", "Cesarini"),
    ("Nico", "Di Domenica"),
    ("Marco", "Fattore"),
    ("Claudio", "Ferretti"),
    ("Elisabetta", "Fersini"),
    ("Paola", "Rebora"),
    ("Fabio Antonio", "Stella"),
]

# Raccolta risultati
orcid_data = []
for name, surname in professori:
    print(f"🔍 Cercando {name} {surname}")
    matches = search_orcid_detailed(name, surname)
    for match in matches:
        match["Searched Name"] = name
        match["Searched Surname"] = surname
        orcid_data.append(match)
    time.sleep(1.5)

# Salvataggio
data = pd.DataFrame(orcid_data)
# Out:
# 🔍 Cercando Alberta Argia Andreotti
# 🔍 Cercando Davide Paolo Bernasconi
# 🔍 Cercando Mirko Cesarini
# 🔍 Cercando Nico Di Domenica
# 🔍 Cercando Marco Fattore
# 🔍 Cercando Claudio Ferretti
# 🔍 Cercando Elisabetta Fersini
# 🔍 Cercando Paola Rebora
# 🔍 Cercando Fabio Antonio Stella

# %%
data
# Out:
#                ORCID ID     First Name   Last Name Other Names  \
# 0   0000-0001-8771-5428   DAVIDE PAOLO  BERNASCONI
# 1   0000-0001-6043-3367          Paolo  Bernasconi
# 2   0000-0001-9601-0403          Mirko    Cesarini
# 3   0009-0004-3430-8326           Nico  Di Stefano
# 4   0009-0001-4949-0624           Nico    Di Fonte
# 5   0000-0002-6624-8637          MARCO     FATTORE
# 6   0000-0002-5562-7893        Claudio    Ferretti
# 7   0000-0001-9582-5045        Claudio    Ferretti
# 8   0000-0002-8987-100X     Elisabetta     Fersini
# 9   0000-0003-0606-5852          PAOLA      REBORA
# 10  0000-0002-1394-0507  FABIO ANTONIO      STELLA
# 11  0000-0002-2670-9873       Leonardo      Stella
#
#                                          Affiliations  Searched Name  \
# 0                                                       Davide Paolo
# 1   Fondazione IRCCS Policlinico San Matteo; UNIVE...   Davide Paolo
# 2                                                              Mirko
# 3                               University of Brescia           Nico
# 4                              University of L'Aquila           Nico
# 5                                                              Marco
# 6                                                            Claudio
# 7                                                            Claudio
# 8                                                         Elisabetta
# 9                                                              Paola
# 10                                                     Fabio Antonio
# 11  Higher Education Academy; IEEE Foundation; NTT...  Fabio Antonio
#
#    Searched Surname
# 0        Bernasconi
# 1        Bernasconi
# 2          Cesarini
# 3       Di Domenica
# 4       Di Domenica
# 5           Fattore
# 6          Ferretti
# 7          Ferretti
# 8           Fersini
# 9            Rebora
# 10           Stella
# 11           Stella

# %%
def get_orcid_details(orcid_id):
    url = f"https://pub.orcid.org/v3.0/{orcid_id}"
    headers = {"Accept": "application/json"}
    
    try:
        res = requests.get(url, headers=headers, timeout=10)
        res.raise_for_status()
    except Exception as e:
        print(f"❌ Errore per ORCID {orcid_id}: {e}")
        return {
            "Biography": None,
            "Country": None,
            "Research URLs": None,
            "Affiliations Detailed": None,
            "Publications Titles": None,
            "DOIs": None
        }

    data = res.json()
    person = data.get("person", {})
    activities = data.get("activities-summary", {})

    # === Biografia e paese ===
    biography = person.get("biography", {}).get("content") if person.get("biography") else None

    address_list = person.get("addresses", {}).get("address", [])
    country = None
    if address_list and isinstance(address_list, list):
        country = address_list[0].get("country", {}).get("value")

    # === Researcher URLs ===
    researcher_urls = []
    urls = person.get("researcher-urls", {}).get("researcher-url", [])
    if isinstance(urls, list):
        researcher_urls = [u.get("url", {}).get("value") for u in urls if u.get("url")]

    # === Affiliazioni ===
    employments = activities.get("employments", {}).get("employment-summary", [])
    current_affiliation = "; ".join(
        [f"{e.get('organization', {}).get('name', '')} ({e.get('role-title', '')})"
         for e in employments if e.get("organization")]
    )

    # === Pubblicazioni ===
    works = activities.get("works", {}).get("group", [])
    work_titles = []
    dois = []
    for w in works:
        summary = w.get("work-summary", [{}])[0]
        title = summary.get("title", {}).get("title", {}).get("value", "")
        if title:
            work_titles.append(title)
        external_ids = summary.get("external-ids", {}).get("external-id", [])
        for eid in external_ids:
            if eid.get("external-id-type") == "doi":
                dois.append(eid.get("external-id-value"))

    return {
        "Biography": biography,
        "Country": country,
        "Research URLs": "; ".join(filter(None, researcher_urls)),
        "Affiliations Detailed": current_affiliation,
        "Publications Titles": "; ".join(work_titles[:5]),
        "DOIs": "; ".join(dois[:5])
    }

# === Carica dataset ORCID ID ===
data = data

# === Estrai dettagli da ogni ORCID ===
details = []
for i, row in data.iterrows():
    orcid_id = row["ORCID ID"]
    print(f"Estraendo dettagli per {orcid_id}")
    info = get_orcid_details(orcid_id)
    details.append(info)
    time.sleep(1.5)  # evita rate limiting

# === Aggiungi nuove colonne al DataFrame originale ===
details_df = pd.DataFrame(details)
df_full = pd.concat([data, details_df], axis=1)

# === Salva il file finale ===
df_full.to_csv("orcid_professori_arricchito.csv", index=False)
# Out:
# 🔍 Estraendo dettagli per 0000-0001-8771-5428
# 🔍 Estraendo dettagli per 0000-0001-6043-3367
# 🔍 Estraendo dettagli per 0000-0001-9601-0403
# 🔍 Estraendo dettagli per 0009-0004-3430-8326
# 🔍 Estraendo dettagli per 0009-0001-4949-0624
# 🔍 Estraendo dettagli per 0000-0002-6624-8637
# 🔍 Estraendo dettagli per 0000-0002-5562-7893
# 🔍 Estraendo dettagli per 0000-0001-9582-5045
# 🔍 Estraendo dettagli per 0000-0002-8987-100X
# 🔍 Estraendo dettagli per 0000-0003-0606-5852
# 🔍 Estraendo dettagli per 0000-0002-1394-0507
# 🔍 Estraendo dettagli per 0000-0002-2670-9873
# ✅ File salvato come orcid_professori_arricchito.csv

# %%
df_full
# Out:
#                ORCID ID     First Name   Last Name  Other Names  \
# 0   0000-0001-8771-5428   DAVIDE PAOLO  BERNASCONI          NaN
# 1   0000-0001-6043-3367          Paolo  Bernasconi          NaN
# 2   0000-0001-9601-0403          Mirko    Cesarini          NaN
# 3   0009-0004-3430-8326           Nico  Di Stefano          NaN
# 4   0009-0001-4949-0624           Nico    Di Fonte          NaN
# 5   0000-0002-6624-8637          MARCO     FATTORE          NaN
# 6   0000-0002-5562-7893        Claudio    Ferretti          NaN
# 7   0000-0001-9582-5045        Claudio    Ferretti          NaN
# 8   0000-0002-8987-100X     Elisabetta     Fersini          NaN
# 9   0000-0003-0606-5852          PAOLA      REBORA          NaN
# 10  0000-0002-1394-0507  FABIO ANTONIO      STELLA          NaN
# 11  0000-0002-2670-9873       Leonardo      Stella          NaN
#
#                                          Affiliations  Searched Name  \
# 0                                                 NaN   Davide Paolo
# 1   Fondazione IRCCS Policlinico San Matteo; UNIVE...   Davide Paolo
# 2                                                 NaN          Mirko
# 3                               University of Brescia           Nico
# 4                              University of L'Aquila           Nico
# 5                                                 NaN          Marco
# 6                                                 NaN        Claudio
# 7                                                 NaN        Claudio
# 8                                                 NaN     Elisabetta
# 9                                                 NaN          Paola
# 10                                                NaN  Fabio Antonio
# 11  Higher Education Academy; IEEE Foundation; NTT...  Fabio Antonio
#
#    Searched Surname                                          Biography  \
# 0        Bernasconi                                               None
# 1        Bernasconi                                               None
# 2          Cesarini                                               None
# 3       Di Domenica                                               None
# 4       Di Domenica                                               None
# 5           Fattore                                               None
# 6          Ferretti                                               None
# 7          Ferretti                                               None
# 8           Fersini                                               None
# 9            Rebora                                               None
# 10           Stella                                               None
# 11           Stella  Leonardo Stella received the Laurea Triennale ...
#
#    Country                                     Research URLs  \
# 0     None
# 1     None
# 2     None  http://www.statistica.unimib.it/utenti/cesarini/
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11      GB                         http://leonardostella.com
#
#    Affiliations Detailed                                Publications Titles  \
# 0                         How Are Diagnosis-Related Groups and Staffing ...
# 1                         Donor Cell Acute Myeloid Leukemia after Hemato...
# 2                         Classifying online Job Advertisements through ...
# 3
# 4                         Early prediction of spinodal-like relaxation e...
# 5                         A fuzzy posetic toolbox for multi-criteria eva...
# 6
# 7                         Exploring the Prompt Space of Large Language M...
# 8                         Unraveling Disagreement Constituents in Hatefu...
# 9                         Development and Psychometric Testing of the Ca...
# 10                        Comparing Deep Reinforcement Learning Algorith...
# 11                        A novel porosity prediction framework based on...
#
#                                                  DOIs
# 0   10.3390/healthcare12191988; 10.3390/jcm1302061...
# 1   10.3390/genes14112085; 10.3390/cancers13133170...
# 2   10.1016/j.future.2018.03.035; 10.1002/sam.1137...
# 3
# 4     10.1063/5.0211031; 10.1016/j.molliq.2023.123425
# 5   10.1007/s10479-024-06352-3; 10.7866/HPE-RPE.23...
# 6
# 7   10.1145/3638529.3654049; 10.3390/a16100478; 10...
# 8   10.1007/978-3-031-56066-8_3; 10.3390/math11204...
# 9   10.1177/26350106251336309; 10.1007/s00134-025-...
# 10  10.1007/978-3-031-74640-6_37; 10.1111/jopy.129...
# 11  10.1016/j.scriptamat.2024.116377; 10.1016/j.or...

# %% [markdown]
# ### Semantic matching

# %%
# Costruzione stringhe semantiche
def build_professor_string(row):
    fields = [
        row.get("name", ""),
        row.get("surname", ""),
        #row.get("profile_url", ""),
        #row.get("role", ""),
        #row.get("ssd", ""),
        #row.get("gsd", ""),
        #row.get("department", ""),
        row.get("publications", "")
    ]
    return " ".join([str(f).strip() for f in fields if pd.notna(f) and str(f).strip() != ""])

def build_orcid_string(row):
    fields = [
        row.get("First Name", ""),
        row.get("Last Name", ""),
        #row.get("Affiliations", ""),
        #row.get("Biography", ""),
        row.get("Publications Titles", ""),
        #row.get("Verified Email", ""),
        #row.get("Personal Website", "")
    ]
    return " ".join([str(f).strip() for f in fields if pd.notna(f) and str(f).strip() != ""])

# Carica modello
model = SentenceTransformer("all-MiniLM-L6-v2")

# Inizializza risultati
results = []

# Itera su ciascun professore di df
for i, prof_row in df.iterrows():
    prof_name = prof_row["name"]
    prof_surname = prof_row["surname"]

    # Filtra df_full con lo stesso nome/cognome cercato
    df_candidates = df_full[
        (df_full["Searched Name"].str.strip().str.lower() == prof_name.strip().lower()) &
        (df_full["Searched Surname"].str.strip().str.lower() == prof_surname.strip().lower())
    ]

    # Se non ci sono candidati, salta
    if df_candidates.empty:
        results.append({
            "Best Match ORCID Text": None,
            "Similarity Score": None,
            "Matched ORCID ID": None
        })
        continue

    # Costruisci stringhe
    prof_text = build_professor_string(prof_row)
    candidate_texts = df_candidates.apply(build_orcid_string, axis=1)

    # Embedding
    emb_prof = model.encode(prof_text, convert_to_tensor=True)
    emb_cands = model.encode(candidate_texts.tolist(), convert_to_tensor=True)

    # Similarità
    scores = util.cos_sim(emb_prof, emb_cands)[0]
    best_idx = scores.argmax().item()
    best_score = scores[best_idx].item()

    best_match_row = df_candidates.iloc[best_idx]

    results.append({
        "Best Match ORCID Text": candidate_texts.iloc[best_idx],
        "Similarity Score": best_score,
        "Matched ORCID ID": best_match_row.get("ORCID ID", None),
        "Matched First Name": best_match_row.get("First Name", None),
        "Matched Last Name": best_match_row.get("Last Name", None)
    })


# Unisci con il DataFrame originale
results_df = pd.DataFrame(results)
df_matched = pd.concat([df.reset_index(drop=True), results_df], axis=1)

# Salva
df_matched.to_csv("matched_professori_filtered.csv", index=False)
df_matched
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
#             name      surname                                    profile_url  \
# 0  Alberta Argia    Andreotti  https://www.unimib.it/alberta-argia-andreotti
# 1   Davide Paolo   Bernasconi  https://www.unimib.it/davide-paolo-bernasconi
# 2          Mirko     Cesarini           https://www.unimib.it/mirko-cesarini
# 3           Nico  Di Domenica         https://www.unimib.it/nico-di-domenica
# 4          Marco      Fattore            https://www.unimib.it/marco-fattore
# 5        Claudio     Ferretti         https://www.unimib.it/claudio-ferretti
# 6     Elisabetta      Fersini       https://www.unimib.it/elisabetta-fersini
# 7          Paola       Rebora             https://www.unimib.it/paola-rebora
# 8  Fabio Antonio       Stella     https://www.unimib.it/fabio-antonio-stella
#
#         phone                     role  \
# 0  0264487579  Professoressa ordinaria
# 1  0264488098     Professore associato
# 2  0264485849              Ricercatore
# 3         NaN                      NaN
# 4  0264483227     Professore ordinario
# 5  0264487819     Professore associato
# 6  0264487896  Professoressa associata
# 7  0264488165  Professoressa associata
# 8  0264487837     Professore ordinario
#
#                                                  ssd  \
# 0  Sociologia dei processi economici e del lavoro...
# 1                      Statistica medica (MEDS-24/A)
# 2  Sistemi di elaborazione delle informazioni (II...
# 3                                                NaN
# 4                   Statistica economica (STAT-02/A)
# 5                            Informatica (INFO-01/A)
# 6                            Informatica (INFO-01/A)
# 7                      Statistica medica (MEDS-24/A)
# 8                            Informatica (INFO-01/A)
#
#                                                  gsd  \
# 0  SOCIOLOGIA DEI PROCESSI ECONOMICI, DEL LAVORO,...
# 1  STATISTICA MEDICA, IGIENE GENERALE E APPLICATA...
# 2  SISTEMI DI ELABORAZIONE DELLE INFORMAZIONI (09...
# 3                                                NaN
# 4                  STATISTICA ECONOMICA (13/STAT-02)
# 5                           INFORMATICA (01/INFO-01)
# 6                           INFORMATICA (01/INFO-01)
# 7  STATISTICA MEDICA, IGIENE GENERALE E APPLICATA...
# 8                           INFORMATICA (01/INFO-01)
#
#                                           department  \
# 0       DIPARTIMENTO DI SOCIOLOGIA E RICERCA SOCIALE
# 1  DIPARTIMENTO DI MEDICINA E CHIRURGIA (SCHOOL O...
# 2   DIPARTIMENTO DI STATISTICA E METODI QUANTITATIVI
# 3                                                NaN
# 4   DIPARTIMENTO DI STATISTICA E METODI QUANTITATIVI
# 5  DIPARTIMENTO DI INFORMATICA, SISTEMISTICA E CO...
# 6  DIPARTIMENTO DI INFORMATICA, SISTEMISTICA E CO...
# 7  DIPARTIMENTO DI MEDICINA E CHIRURGIA (SCHOOL O...
# 8  DIPARTIMENTO DI INFORMATICA, SISTEMISTICA E CO...
#
#                           office  \
# 0   U07,  Piano: 3,  Stanza: 352
# 1  U28,  Piano: 0,  Stanza: T003
# 2  U07,  Piano: 4,  Stanza: 4133
# 3                            NaN
# 4  U07,  Piano: 4,  Stanza: 4133
# 5  U14,  Piano: 2,  Stanza: 2053
# 6  U14,  Piano: 2,  Stanza: 2016
# 7  U28,  Piano: 0,  Stanza: T002
# 8  U14,  Piano: 2,  Stanza: 2046
#
#                                         publications  \
# 0  Andreotti, A., Coletto, D., Rio, A. (2024). St...
# 1  Capsoni, N., Azin, G., Scarnera, M., Bettina, ...
# 2  Ravenda, F., Cesarini, M., Peluso, S., Mira, A...
# 3                                                NaN
# 4  Fattore, M. (2025). Complexity reduction of mu...
# 5  Saletta, M., Ferretti, C. (2024). Exploring th...
# 6  Batini, C., Santucci, G., Palmonari, M., Bella...
# 7  Rebora, P., Antolini, L., Glidden, D., & Valse...
# 8  Acerbi, E., Viganò, E., Poidinger, M., Mortell...
#
#                                Best Match ORCID Text  Similarity Score  \
# 0                                               None               NaN
# 1  DAVIDE PAOLO BERNASCONI How Are Diagnosis-Rela...          0.321503
# 2  Mirko Cesarini Classifying online Job Advertis...          0.209971
# 3                                    Nico Di Stefano          0.665949
# 4  MARCO FATTORE A fuzzy posetic toolbox for mult...          0.658271
# 5  Claudio Ferretti Exploring the Prompt Space of...          0.811079
# 6  Elisabetta Fersini Unraveling Disagreement Con...          0.470735
# 7  PAOLA REBORA Development and Psychometric Test...          0.215637
# 8  FABIO ANTONIO STELLA Comparing Deep Reinforcem...          0.503208
#
#       Matched ORCID ID Matched First Name Matched Last Name
# 0                 None                NaN               NaN
# 1  0000-0001-8771-5428       DAVIDE PAOLO        BERNASCONI
# 2  0000-0001-9601-0403              Mirko          Cesarini
# 3  0009-0004-3430-8326               Nico        Di Stefano
# 4  0000-0002-6624-8637              MARCO           FATTORE
# 5  0000-0001-9582-5045            Claudio          Ferretti
# 6  0000-0002-8987-100X         Elisabetta           Fersini
# 7  0000-0003-0606-5852              PAOLA            REBORA
# 8  0000-0002-1394-0507      FABIO ANTONIO            STELLA

# %%
df
# Out:
#        Last name           Name         SSD                orcid
# 0      Andreotti  Alberta Argia      SPS/09                 None
# 1     Bernasconi   Davide Paolo      MED/01                 None
# 2         Bianco         Simone      INF/01  0000-0002-7070-1545
# 3        Bissiri  Pier Giovanni   SECS-S/01  0000-0003-3769-6649
# 4       Cesarini          Mirko  ING-INF/05                 None
# 5         Chicco         Davide      INF/01  0000-0001-9655-7142
# 6       Ciavotta        Michele      INF/01  0000-0002-2480-966X
# 7   Della Vedova       Gianluca      INF/01  0000-0001-5584-3089
# 8    Di Domenica           Nico   SECS-P/08                 None
# 9        Fattore          Marco   SECS-S/03                 None
# 10      Ferretti        Claudio      INF/01                 None
# 11       Fersini     Elisabetta      INF/01                 None
# 12         Forte     Gianfranco   SECS-P/11  0000-0002-3412-4162
# 13       Gianini       Gabriele      INF/01  0000-0001-5186-0199
# 14      Guerzoni          Marco   SECS-P/06  0000-0001-7415-0771
# 15       Maurino         Andrea      INF/01  0000-0001-9803-3668
# 16      Mercorio          Fabio      INF/01  0000-0001-6864-2702
# 17       Messina           Enza      MAT/09  0000-0002-4062-0824
# 18         Monti         Gianna   SECS-S/01  0000-0002-7952-3618
# 19       Moretto         Enrico   SECS-S/06  0000-0002-3436-1395
# 20    Napoletano          Paolo      INF/01  0000-0001-9112-0574
# 21      Paganoni          Marco      FIS/01  0000-0003-2461-275X
# 22     Palmonari         Matteo      INF/01  0000-0002-1801-5118
# 23          Pasi      Gabriella      INF/01  0000-0002-6080-8170
# 24     Pelagatti         Matteo   SECS-S/03  0000-0002-1860-7535
# 25       Pennoni         Fulvia   SECS-S/01  0000-0002-6331-7211
# 26       Pescini          Dario      INF/01  0000-0002-3090-4823
# 27      Presotto           Luca      FIS/07  0000-0002-8809-0877
# 28        Rebora          Paola      MED/01                 None
# 29        Stella  Fabio Antonio      MAT/09                 None
# 30       Viviani          Marco      INF/01  0000-0002-2274-9050

# %% [markdown]
# ### Add New ORCID

# %%
df_professori_matched = df_matched
df_orcid_list = df

# Normalizza nomi e cognomi
df_professori_matched["full_name"] = (
    df_professori_matched["name"].str.strip().str.lower() + " " +
    df_professori_matched["surname"].str.strip().str.lower()
)

df_orcid_list["full_name"] = (
    df_orcid_list["Name"].str.strip().str.lower() + " " +
    df_orcid_list["Last name"].str.strip().str.lower()
)

# Crea dizionario: full_name -> orcid (solo se presente)
orcid_map = df_professori_matched.set_index("full_name")["Matched ORCID ID"].dropna().to_dict()

# Applica solo dove orcid è mancante
df_orcid_list["orcid"] = df_orcid_list.apply(
    lambda row: orcid_map.get(row["full_name"], row["orcid"]) if pd.isna(row["orcid"]) else row["orcid"],
    axis=1
)

# Rimuovi colonna temporanea
df_orcid_list.drop(columns=["full_name"], inplace=True)

# Salva risultato
df_orcid_list.to_csv("orcid_list_updated.csv", index=False)

# %%
df_orcid_list = df_orcid_list[
    ~(
        ((df_orcid_list["Name"].str.strip().str.lower() == "alberta argia") & 
         (df_orcid_list["Last name"].str.strip().str.lower() == "andreotti")) |
        ((df_orcid_list["Name"].str.strip().str.lower() == "nico") & 
         (df_orcid_list["Last name"].str.strip().str.lower() == "di domenica"))
    )
]
df_orcid_list
# Out:
#        Last name           Name         SSD                orcid
# 1     Bernasconi   Davide Paolo      MED/01  0000-0001-8771-5428
# 2         Bianco         Simone      INF/01  0000-0002-7070-1545
# 3        Bissiri  Pier Giovanni   SECS-S/01  0000-0003-3769-6649
# 4       Cesarini          Mirko  ING-INF/05  0000-0001-9601-0403
# 5         Chicco         Davide      INF/01  0000-0001-9655-7142
# 6       Ciavotta        Michele      INF/01  0000-0002-2480-966X
# 7   Della Vedova       Gianluca      INF/01  0000-0001-5584-3089
# 9        Fattore          Marco   SECS-S/03  0000-0002-6624-8637
# 10      Ferretti        Claudio      INF/01  0000-0001-9582-5045
# 11       Fersini     Elisabetta      INF/01  0000-0002-8987-100X
# 12         Forte     Gianfranco   SECS-P/11  0000-0002-3412-4162
# 13       Gianini       Gabriele      INF/01  0000-0001-5186-0199
# 14      Guerzoni          Marco   SECS-P/06  0000-0001-7415-0771
# 15       Maurino         Andrea      INF/01  0000-0001-9803-3668
# 16      Mercorio          Fabio      INF/01  0000-0001-6864-2702
# 17       Messina           Enza      MAT/09  0000-0002-4062-0824
# 18         Monti         Gianna   SECS-S/01  0000-0002-7952-3618
# 19       Moretto         Enrico   SECS-S/06  0000-0002-3436-1395
# 20    Napoletano          Paolo      INF/01  0000-0001-9112-0574
# 21      Paganoni          Marco      FIS/01  0000-0003-2461-275X
# 22     Palmonari         Matteo      INF/01  0000-0002-1801-5118
# 23          Pasi      Gabriella      INF/01  0000-0002-6080-8170
# 24     Pelagatti         Matteo   SECS-S/03  0000-0002-1860-7535
# 25       Pennoni         Fulvia   SECS-S/01  0000-0002-6331-7211
# 26       Pescini          Dario      INF/01  0000-0002-3090-4823
# 27      Presotto           Luca      FIS/07  0000-0002-8809-0877
# 28        Rebora          Paola      MED/01  0000-0003-0606-5852
# 29        Stella  Fabio Antonio      MAT/09  0000-0002-1394-0507
# 30       Viviani          Marco      INF/01  0000-0002-2274-9050

# %%
df_orcid_list.to_csv('authors_complete_ds.csv')

# %%
courses = [
    "Data Science Lab in Medicine",
    "Digital Signal and Image Management",
    "Foundations of Probability and Statistics",
    "Service Science",
    "Green Computing",
    "Technological Infrastructures for Data Science",
    "Foundations of Computer Science",
    "Data Science Lab",
    "Cybersecurity for Data Science",
    "Natural Language Processing",
    "Financial Markets Analytics",
    "Green Computing",
    "Economics for Data Science",
    "Data Management",
    "Business Intelligence",
    "Decision Models",
    "High Dimensional Data Analysis",
    "Data Science Lab in Business and Marketing",
    "Foundations of Deep Learning",
    "Data Science Lab in Environment and Physics",
    "Data Semantics",
    "Text Mining and Search",
    "Streaming Data Management and Time Series Analysis",
    "Statistical Modeling",
    "Data Science Lab in Biosciences",
    "Data Science Lab in Medicine",
    "Big Data in Public Health",
    "Machine Learning",
    "Text Mining and Search"
]


df_orcid_list['Course'] = courses
df_orcid_list
# Out:
# /var/folders/7y/h7b4hxf568n1y6xlpl8vf6340000gn/T/ipykernel_49524/2004441958.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_orcid_list['Course'] = courses
#        Last name           Name         SSD                orcid  \
# 1     Bernasconi   Davide Paolo      MED/01  0000-0001-8771-5428
# 2         Bianco         Simone      INF/01  0000-0002-7070-1545
# 3        Bissiri  Pier Giovanni   SECS-S/01  0000-0003-3769-6649
# 4       Cesarini          Mirko  ING-INF/05  0000-0001-9601-0403
# 5         Chicco         Davide      INF/01  0000-0001-9655-7142
# 6       Ciavotta        Michele      INF/01  0000-0002-2480-966X
# 7   Della Vedova       Gianluca      INF/01  0000-0001-5584-3089
# 9        Fattore          Marco   SECS-S/03  0000-0002-6624-8637
# 10      Ferretti        Claudio      INF/01  0000-0001-9582-5045
# 11       Fersini     Elisabetta      INF/01  0000-0002-8987-100X
# 12         Forte     Gianfranco   SECS-P/11  0000-0002-3412-4162
# 13       Gianini       Gabriele      INF/01  0000-0001-5186-0199
# 14      Guerzoni          Marco   SECS-P/06  0000-0001-7415-0771
# 15       Maurino         Andrea      INF/01  0000-0001-9803-3668
# 16      Mercorio          Fabio      INF/01  0000-0001-6864-2702
# 17       Messina           Enza      MAT/09  0000-0002-4062-0824
# 18         Monti         Gianna   SECS-S/01  0000-0002-7952-3618
# 19       Moretto         Enrico   SECS-S/06  0000-0002-3436-1395
# 20    Napoletano          Paolo      INF/01  0000-0001-9112-0574
# 21      Paganoni          Marco      FIS/01  0000-0003-2461-275X
# 22     Palmonari         Matteo      INF/01  0000-0002-1801-5118
# 23          Pasi      Gabriella      INF/01  0000-0002-6080-8170
# 24     Pelagatti         Matteo   SECS-S/03  0000-0002-1860-7535
# 25       Pennoni         Fulvia   SECS-S/01  0000-0002-6331-7211
# 26       Pescini          Dario      INF/01  0000-0002-3090-4823
# 27      Presotto           Luca      FIS/07  0000-0002-8809-0877
# 28        Rebora          Paola      MED/01  0000-0003-0606-5852
# 29        Stella  Fabio Antonio      MAT/09  0000-0002-1394-0507
# 30       Viviani          Marco      INF/01  0000-0002-2274-9050
#
#                                                Course
# 1                        Data Science Lab in Medicine
# 2                 Digital Signal and Image Management
# 3           Foundations of Probability and Statistics
# 4                                     Service Science
# 5                                     Green Computing
# 6      Technological Infrastructures for Data Science
# 7                     Foundations of Computer Science
# 9                                    Data Science Lab
# 10                     Cybersecurity for Data Science
# 11                        Natural Language Processing
# 12                        Financial Markets Analytics
# 13                                    Green Computing
# 14                         Economics for Data Science
# 15                                    Data Management
# 16                              Business Intelligence
# 17                                    Decision Models
# 18                     High Dimensional Data Analysis
# 19         Data Science Lab in Business and Marketing
# 20                       Foundations of Deep Learning
# 21        Data Science Lab in Environment and Physics
# 22                                     Data Semantics
# 23                             Text Mining and Search
# 24  Streaming Data Management and Time Series Anal...
# 25                               Statistical Modeling
# 26                    Data Science Lab in Biosciences
# 27                       Data Science Lab in Medicine
# 28                          Big Data in Public Health
# 29                                   Machine Learning
# 30                             Text Mining and Search

# %%
df_orcid_list.to_csv('authors_complete_ds.csv')

# %% [markdown]
# ### Create Complete Dataset for Internal professors

# %%
df_complete = pd.read_csv("../data/authors/authors_complete.csv")
df_orcid = pd.read_csv("../data/authors/authors_complete_ds.csv")
df_orcid
# Out:
#     Unnamed: 0     Last name           Name         SSD                orcid  \
# 0            1    Bernasconi   Davide Paolo      MED/01  0000-0001-8771-5428
# 1            2        Bianco         Simone      INF/01  0000-0002-7070-1545
# 2            3       Bissiri  Pier Giovanni   SECS-S/01  0000-0003-3769-6649
# 3            4      Cesarini          Mirko  ING-INF/05  0000-0001-9601-0403
# 4            5        Chicco         Davide      INF/01  0000-0001-9655-7142
# 5            6      Ciavotta        Michele      INF/01  0000-0002-2480-966X
# 6            7  Della Vedova       Gianluca      INF/01  0000-0001-5584-3089
# 7            9       Fattore          Marco   SECS-S/03  0000-0002-6624-8637
# 8           10      Ferretti        Claudio      INF/01  0000-0001-9582-5045
# 9           11       Fersini     Elisabetta      INF/01  0000-0002-8987-100X
# 10          12         Forte     Gianfranco   SECS-P/11  0000-0002-3412-4162
# 11          13       Gianini       Gabriele      INF/01  0000-0001-5186-0199
# 12          14      Guerzoni          Marco   SECS-P/06  0000-0001-7415-0771
# 13          15       Maurino         Andrea      INF/01  0000-0001-9803-3668
# 14          16      Mercorio          Fabio      INF/01  0000-0001-6864-2702
# 15          17       Messina           Enza      MAT/09  0000-0002-4062-0824
# 16          18         Monti         Gianna   SECS-S/01  0000-0002-7952-3618
# 17          19       Moretto         Enrico   SECS-S/06  0000-0002-3436-1395
# 18          20    Napoletano          Paolo      INF/01  0000-0001-9112-0574
# 19          21      Paganoni          Marco      FIS/01  0000-0003-2461-275X
# 20          22     Palmonari         Matteo      INF/01  0000-0002-1801-5118
# 21          23          Pasi      Gabriella      INF/01  0000-0002-6080-8170
# 22          24     Pelagatti         Matteo   SECS-S/03  0000-0002-1860-7535
# 23          25       Pennoni         Fulvia   SECS-S/01  0000-0002-6331-7211
# 24          26       Pescini          Dario      INF/01  0000-0002-3090-4823
# 25          27      Presotto           Luca      FIS/07  0000-0002-8809-0877
# 26          28        Rebora          Paola      MED/01  0000-0003-0606-5852
# 27          29        Stella  Fabio Antonio      MAT/09  0000-0002-1394-0507
# 28          30       Viviani          Marco      INF/01  0000-0002-2274-9050
#
#                                                Course
# 0                        Data Science Lab in Medicine
# 1                 Digital Signal and Image Management
# 2           Foundations of Probability and Statistics
# 3                                     Service Science
# 4                                     Green Computing
# 5      Technological Infrastructures for Data Science
# 6                     Foundations of Computer Science
# 7                                    Data Science Lab
# 8                      Cybersecurity for Data Science
# 9                         Natural Language Processing
# 10                        Financial Markets Analytics
# 11                                    Green Computing
# 12                         Economics for Data Science
# 13                                    Data Management
# 14                              Business Intelligence
# 15                                    Decision Models
# 16                     High Dimensional Data Analysis
# 17         Data Science Lab in Business and Marketing
# 18                       Foundations of Deep Learning
# 19        Data Science Lab in Environment and Physics
# 20                                     Data Semantics
# 21                             Text Mining and Search
# 22  Streaming Data Management and Time Series Anal...
# 23                               Statistical Modeling
# 24                    Data Science Lab in Biosciences
# 25                       Data Science Lab in Medicine
# 26                          Big Data in Public Health
# 27                                   Machine Learning
# 28                             Text Mining and Search

# %%
import pandas as pd

# Carica i due dataset
df_complete = pd.read_csv("../data/authors/authors_complete.csv")
df_complete = df_complete[['Last name','Name','hindex','openalex id',	'institutions id', 'institutions name',	'topics']]
df_orcid = pd.read_csv("../data/authors/authors_complete_ds.csv")

# Rimuovi la colonna "Unnamed: 0" se presente
for df in [df_complete, df_orcid]:
    if "Unnamed: 0" in df.columns:
        df.drop(columns=["Unnamed: 0"], inplace=True)

# Unione basata su nome e cognome
df_merged = pd.merge(df_complete, df_orcid, on=["Name", "Last name"], how="left")

# Visualizza il risultato
df_merged.head()
df_merged.to_csv('../data/authors/authors_internal.csv')

# %%
df_merged
# Out:
#        Last name           Name  hindex                       openalex id  \
# 0     Bernasconi   Davide Paolo    24.0  https://openalex.org/A5050512903
# 1         Bianco         Simone    34.0  https://openalex.org/A5013570285
# 2        Bissiri  Pier Giovanni     7.0  https://openalex.org/A5074768639
# 3       Cesarini          Mirko    15.0  https://openalex.org/A5049259722
# 4         Chicco         Davide    27.0  https://openalex.org/A5011556172
# 5       Ciavotta        Michele    16.0  https://openalex.org/A5079768184
# 6   Della Vedova       Gianluca    22.0  https://openalex.org/A5059679442
# 7        Fattore          Marco    16.0  https://openalex.org/A5006214257
# 8       Ferretti        Claudio    47.0  https://openalex.org/A5033044137
# 9        Fersini     Elisabetta    23.0  https://openalex.org/A5005702955
# 10         Forte     Gianfranco     6.0  https://openalex.org/A5083598816
# 11       Gianini       Gabriele    32.0  https://openalex.org/A5037738148
# 12      Guerzoni          Marco     6.0  https://openalex.org/A5102799538
# 13       Maurino         Andrea    21.0  https://openalex.org/A5067371383
# 14      Mercorio          Fabio    22.0  https://openalex.org/A5047827615
# 15       Messina           Enza    22.0  https://openalex.org/A5061496529
# 16         Monti         Gianna    13.0  https://openalex.org/A5053644955
# 17       Moretto         Enrico     9.0  https://openalex.org/A5014795659
# 18    Napoletano          Paolo    34.0  https://openalex.org/A5053344554
# 19      Paganoni          Marco   145.0  https://openalex.org/A5100656992
# 20     Palmonari         Matteo    21.0  https://openalex.org/A5065845420
# 21          Pasi      Gabriella    41.0  https://openalex.org/A5066756066
# 22     Pelagatti         Matteo    16.0  https://openalex.org/A5041483987
# 23       Pennoni         Fulvia    15.0  https://openalex.org/A5021943787
# 24       Pescini          Dario    21.0  https://openalex.org/A5065568541
# 25      Presotto           Luca    25.0  https://openalex.org/A5021078706
# 26        Rebora          Paola    32.0  https://openalex.org/A5055188160
# 27        Stella  Fabio Antonio    19.0  https://openalex.org/A5020281960
# 28       Viviani          Marco    25.0  https://openalex.org/A5074645479
#
#                                       institutions id  \
# 0   ['https://openalex.org/I66752286', 'https://op...
# 1   ['https://openalex.org/I66752286', 'https://op...
# 2   ['https://openalex.org/I66752286', 'https://op...
# 3   ['https://openalex.org/I66752286', 'https://op...
# 4   ['https://openalex.org/I185261750', 'https://o...
# 5   ['https://openalex.org/I66752286', 'https://op...
# 6   ['https://openalex.org/I66752286', 'https://op...
# 7                  ['https://openalex.org/I66752286']
# 8   ['https://openalex.org/I27837315', 'https://op...
# 9   ['https://openalex.org/I66752286', 'https://op...
# 10  ['https://openalex.org/I66752286', 'https://op...
# 11  ['https://openalex.org/I66752286', 'https://op...
# 12  ['https://openalex.org/I160013858', 'https://o...
# 13  ['https://openalex.org/I66752286', 'https://op...
# 14  ['https://openalex.org/I66752286', 'https://op...
# 15  ['https://openalex.org/I66752286', 'https://op...
# 16                 ['https://openalex.org/I66752286']
# 17  ['https://openalex.org/I106296451', 'https://o...
# 18  ['https://openalex.org/I66752286', 'https://op...
# 19  ['https://openalex.org/I4210140564', 'https://...
# 20  ['https://openalex.org/I66752286', 'https://op...
# 21  ['https://openalex.org/I66752286', 'https://op...
# 22  ['https://openalex.org/I66752286', 'https://op...
# 23  ['https://openalex.org/I66752286', 'https://op...
# 24  ['https://openalex.org/I66752286', 'https://op...
# 25  ['https://openalex.org/I66752286', 'https://op...
# 26  ['https://openalex.org/I66752286', 'https://op...
# 27  ['https://openalex.org/I66752286', 'https://op...
# 28  ['https://openalex.org/I66752286', 'https://op...
#
#                                     institutions name  \
# 0   ['University of Milano-Bicocca', 'Azienda Soci...
# 1   ['University of Milano-Bicocca', 'University o...
# 2   ['University of Milano-Bicocca', 'University o...
# 3   ['University of Milano-Bicocca', 'Center for N...
# 4   ['University of Toronto', 'University of Milan...
# 5   ['University of Milano-Bicocca', 'The Universi...
# 6   ['University of Milano-Bicocca', 'Istituto Naz...
# 7                    ['University of Milano-Bicocca']
# 8   ['University of Michigan', 'AGH University of ...
# 9   ['University of Milano-Bicocca', 'University o...
# 10  ['University of Milano-Bicocca', 'Bocconi Univ...
# 11  ['University of Milano-Bicocca', 'University o...
# 12  ['Istituto Nazionale di Fisica Nucleare', 'Ist...
# 13  ['University of Milano-Bicocca', 'University o...
# 14  ['University of Milano-Bicocca', 'University o...
# 15  ['University of Milano-Bicocca', 'Istituto Zoo...
# 16                   ['University of Milano-Bicocca']
# 17  ['University of Foggia', 'Azienda Ospedaliera ...
# 18  ['University of Milano-Bicocca', 'Istituto Naz...
# 19  ['Istituto Nazionale di Fisica Nucleare, Sezio...
# 20  ['University of Milano-Bicocca', 'Universität ...
# 21  ['University of Milano-Bicocca', 'IT Universit...
# 22  ['University of Milano-Bicocca', 'Center for I...
# 23  ['University of Milano-Bicocca', 'University o...
# 24  ['University of Milano-Bicocca', 'University o...
# 25  ['University of Milano-Bicocca', 'Istituti di ...
# 26  ['University of Milano-Bicocca', 'Azienda Ospe...
# 27  ['University of Milano-Bicocca', 'University o...
# 28  ['University of Milano-Bicocca', 'IT Universit...
#
#                                                topics         SSD  \
# 0   ['Epidemiology', 'Hepatology', 'Oncology', 'Pu...      MED/01
# 1   ['Computer Vision and Pattern Recognition', 'A...      INF/01
# 2   ['Artificial Intelligence', 'Environmental Eng...   SECS-S/01
# 3   ['Management Science and Operations Research',...  ING-INF/05
# 4   ['Molecular Biology', 'Health Information Mana...      INF/01
# 5   ['Information Systems', 'Computer Networks and...      INF/01
# 6   ['Molecular Biology', 'Artificial Intelligence...      INF/01
# 7   ['Physical and Theoretical Chemistry', 'Manage...   SECS-S/03
# 8   ['Nuclear and High Energy Physics', 'Artificia...      INF/01
# 9   ['Artificial Intelligence', 'Statistical and N...      INF/01
# 10  ['Finance', 'Accounting', 'Strategy and Manage...   SECS-P/11
# 11  ['Nuclear and High Energy Physics', 'Radiation...      INF/01
# 12  ['Economics and Econometrics', 'Nuclear and Hi...   SECS-P/06
# 13  ['Artificial Intelligence', 'Information Syste...      INF/01
# 14  ['Artificial Intelligence', 'Management Scienc...      INF/01
# 15  ['Artificial Intelligence', 'Statistical and N...      MAT/09
# 16  ['Artificial Intelligence', 'Environmental Eng...   SECS-S/01
# 17  ['Experimental and Cognitive Psychology', 'Soc...   SECS-S/06
# 18  ['Computer Vision and Pattern Recognition', 'M...      INF/01
# 19  ['Nuclear and High Energy Physics', 'Astronomy...      FIS/01
# 20  ['Artificial Intelligence', 'Management Scienc...      INF/01
# 21  ['Signal Processing', 'Artificial Intelligence...      INF/01
# 22  ['General Economics, Econometrics and Finance'...   SECS-S/03
# 23  ['Management Science and Operations Research',...   SECS-S/01
# 24  ['Molecular Biology', 'Computational Theory an...      INF/01
# 25  ['Radiology, Nuclear Medicine and Imaging', 'P...      FIS/07
# 26  ['Neurology', 'Endocrinology, Diabetes and Met...      MED/01
# 27  ['Artificial Intelligence', 'Management Scienc...      MAT/09
# 28  ['Sociology and Political Science', 'Informati...      INF/01
#
#                   orcid                                             Course
# 0   0000-0001-8771-5428                       Data Science Lab in Medicine
# 1   0000-0002-7070-1545                Digital Signal and Image Management
# 2   0000-0003-3769-6649          Foundations of Probability and Statistics
# 3   0000-0001-9601-0403                                    Service Science
# 4   0000-0001-9655-7142                                    Green Computing
# 5   0000-0002-2480-966X     Technological Infrastructures for Data Science
# 6   0000-0001-5584-3089                    Foundations of Computer Science
# 7   0000-0002-6624-8637                                   Data Science Lab
# 8   0000-0001-9582-5045                     Cybersecurity for Data Science
# 9   0000-0002-8987-100X                        Natural Language Processing
# 10  0000-0002-3412-4162                        Financial Markets Analytics
# 11  0000-0001-5186-0199                                    Green Computing
# 12  0000-0001-7415-0771                         Economics for Data Science
# 13  0000-0001-9803-3668                                    Data Management
# 14  0000-0001-6864-2702                              Business Intelligence
# 15  0000-0002-4062-0824                                    Decision Models
# 16  0000-0002-7952-3618                     High Dimensional Data Analysis
# 17  0000-0002-3436-1395         Data Science Lab in Business and Marketing
# 18  0000-0001-9112-0574                       Foundations of Deep Learning
# 19  0000-0003-2461-275X        Data Science Lab in Environment and Physics
# 20  0000-0002-1801-5118                                     Data Semantics
# 21  0000-0002-6080-8170                             Text Mining and Search
# 22  0000-0002-1860-7535  Streaming Data Management and Time Series Anal...
# 23  0000-0002-6331-7211                               Statistical Modeling
# 24  0000-0002-3090-4823                    Data Science Lab in Biosciences
# 25  0000-0002-8809-0877                       Data Science Lab in Medicine
# 26  0000-0003-0606-5852                          Big Data in Public Health
# 27  0000-0002-1394-0507                                   Machine Learning
# 28  0000-0002-2274-9050                             Text Mining and Search
